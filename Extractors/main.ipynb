# %%
import json, re, sys, os, time
from operator import itemgetter
import numpy as np
import pandas as pd
import networkx as nx
from copy import deepcopy
from utils import HTTPUtils, MatrixIO, FileUtils

# %% [markdown]
# # --------------------
# #### Establish variables, functions, and prefixes
# # --------------------

# %%
final_folder = "final/raw_data_folder/"

# %%
ad = pd.read_csv(final_folder + "util_files/LDProjects.tsv", sep="\t").set_index("index")
ad = ad.to_dict(orient="index")
for k in ad: ad[k] = ad[k]['0']
print ("Linked Data Projects", len(ad))
# Out:
# ('Linked Data Projects', 19)

# %%
ndbc = pd.read_csv(final_folder + "util_files/NBDC_prefix.tsv", sep="\t").set_index("index")
ndbc = ndbc.to_dict(orient="index")
print ("NBDC Graphs", len(ndbc))
# Out:
# ('NBDC Graphs', 25)

# %%
disAllPrefs = pd.read_csv(final_folder + "util_files/ld_onto_prefixes.tsv", sep="\t").set_index("index")
disAllPrefs = disAllPrefs.to_dict(orient="index")
for k in disAllPrefs: disAllPrefs[k] = disAllPrefs[k]['0']
print("Linked data ontology prefixes", len(disAllPrefs))
# Out:
# ('Linked data ontology prefixes', 13)

# %%
ontoLabels = pd.read_csv(final_folder + "util_files/ontology_labels.tsv", sep="\t").set_index("index")
ontoLabels = ontoLabels.to_dict(orient="index")
print("Ontology Labels", len(ontoLabels))
# Out:
# ('Ontology Labels', 55)

# %%
old_dset_mappings = pd.read_csv(final_folder + "util_files/old_dataset_mappings.tsv", sep="\t").set_index("index")
old_dset_mappings = old_dset_mappings.to_dict(orient="index")
for k in old_dset_mappings: old_dset_mappings[k] = old_dset_mappings[k]['0']
old_dset_mappings[''] = ''
print ("Old Dataset Mappings", len(old_dset_mappings))
# Out:
# ('Old Dataset Mappings', 75)

# %%
first_cap_re = re.compile('(.)([A-Z][a-z]+)')
all_cap_re = re.compile('([a-z0-9])([A-Z])')
ap = mfio.load_matrix(final_folder + "network_data/bio2rdf_classdsets.dat")

def parse_camel_case(name):
    s1 = first_cap_re.sub(r'\1_\2', name)
    return all_cap_re.sub(r'\1_\2', s1).lower()

def parse_uri_token(token):
    prop = parse_camel_case(token)
    pparts = re.split("[-_]", prop)
    name = " ".join([x.title() for x in pparts])
    return name

def parseURI(uri):
    nparts = re.split("[#:/]", uri)
    name = parse_uri_token(nparts[len(nparts)-1])
    return name

def model_proc(k):
    if "resource" in k:
        a = parseURI(k).split()
        if len(a) > 1: return "ModelOrganism-" + a[0]
    return "ModelOrganism"

def nbdc_proc(node):
    nparts = re.split("[#:/]", node)
    prefix = node[:len(node)-len(nparts[len(nparts)-1])]
    if prefix in ndbc: return ndbc[prefix]["id"]
    else: return "NBDC"

def bio2rdf_proc(k):
    dsets = []
    if k in ap:
        for m in ap[k]:
            if "bio2rdf" in m:
                a = m.split(".")
                dset = "Bio2Rdf-" + a[len(a)-2].title()
                dsets.append(dset)
            elif "disgenet" in m:
                dset = "DisGenet"
                dsets.append(dset)
        return ":-:".join(dsets)
    else: return "Bio2Rdf"

def pref_dsets_cst(dset_l):
    ndsets = []
    dsets = dset_l.split(":-:")
    for m in dsets:
        if m == 'Pdb': ndsets.append("NBDC")
        elif m == 'BioSamples': ndsets.append('EBI-BioSamples')
        elif m == 'tcga': ndsets.append("LinkedTCGA")
        else: ndsets.append(m)
    return ":-:".join(ndsets)

def det_dset(ami):
    (a, m, i) = ami
    dsets = []
    inst_count = []
    for xi in range(len(m)): 
        x = m[xi]
        ic = i[xi]
        nist = False
        if "linkedlifedata" in x.lower(): 
            dsets.append(x.split("_")[2].split(".")[0].title())
        elif "pubchem" in x.lower(): 
            dsets.append("Pubchem")
        elif "modelorganism" in x.lower(): 
            dsets.append(model_proc(a))
        elif "bio2rdf-" in x.lower(): 
            dsets.append(x.split("_")[2].split(".")[0].title())
        elif "bio2rdf" in x.lower(): 
            b2r_dsets = bio2rdf_proc(a)
            dsets.append(b2r_dsets)
            nist = True
            for k in range(len(b2r_dsets.split(":-:"))):
                inst_count.append(ic)
        elif "nbdc" in x.lower(): 
            dsets.append(nbdc_proc(a))
        else: 
            dsets.append(x.split("_")[2].split(".")[0])
        if not nist:
            inst_count.append(ic)
    dsets = ":-:".join([str(k) for k in dsets])
    return dsets, inst_count

def get_sparql_endpoint(dset):
    if dset in ad: 
        return ad[dset]
    elif dset.split("-")[0] in ad: 
        return ad[dset.split("-")[0]]
    else: 
        return ""

# %%
mfio = MatrixIO()
fu = FileUtils()

# %% [markdown]
# # --------------------
# #### Read in Class Files and CODP-Combined-Network
# # --------------------

# %%
combG = nx.read_gpickle(final_folder + "network_data/combG_c123.gpickle")

# %%
class_list_folder = final_folder + "class_lists/"
class_set_files = fu.get_reqd_fileset(class_list_folder, lambda x: False if "classlist" in x.lower() else True)
class_sets = {}

# %%
ccount = 0
for k in class_set_files:
    a = mfio.load_matrix(class_list_folder + k)
    for m in a: 
        if not m in class_sets: class_sets[m] = {"files": [], "instance_count": []}
        class_sets[m]["files"].append(k)
        class_sets[m]["instance_count"].append(a[m])
        ccount += 1

# %%
print ("Total Class Count", ccount)
# Out:
# ('Total Class Count', 66768)

# %%
print ("Unique Class Count", len(class_sets))
# Out:
# ('Unique Class Count', 57315)

# %%
for k in class_sets:
    a, b = det_dset((k, class_sets[k]["files"], class_sets[k]["instance_count"]))
    class_sets[k]["dsets"] = a
    class_sets[k]["instance_count"] = b

# %%
for k in class_sets:
    class_sets[k]["total_instance_count"] = np.sum(class_sets[k]["instance_count"])

# %% [markdown]
# # --------------------
# #### Create Class Labels
# # --------------------

# %%
uc = []
undsets = {}
for k in combG.nodes():
    if not combG.node[k]["type"] == "class": continue
    if not k in class_sets:
        uc.append((k, combG.node[k]))
        if "dsets" in combG.node[k]: 
            spcdsets = combG.node[k]["dsets"].split(":-:")
            for m in spcdsets:
                if not m in undsets: undsets[m] = []
                undsets[m].append(k)

# %%
for k in undsets:
    print (k, len(undsets[k]))
# Out:
# (u'Pdb', 6)
# ('linkeddrugs', 168)
# (u'BioSamples', 244)
# (u'LinkedSPL', 1)
# ('tcga', 14)

# %%
for k in undsets:
    for m in undsets[k]:
        class_sets[m] = {"files": [], 
                         "dsets": pref_dsets_cst(combG.node[m]["dsets"]), 
                         "instance_count": [combG.node[m]["count"]] if "count" in combG.node[m] else [0], 
                         "total_instance_count": combG.node[m]["count"] if "count" in combG.node[m] else 0}

# %%
found_lab = 0
found_sec_lab = 0
for k in class_sets:
    if combG.has_node(k):
        if "refL1" in combG.node[k]: 
            class_sets[k]["refL1"] = combG.node[k]["refL1"]
            found_lab += 1
        if "sec_label" in combG.node[k]:
            class_sets[k]["sec_label"] = combG.node[k]["sec_label"]
            found_sec_lab += 1
    if not "refL1" in class_sets[k]: class_sets[k]["refL1"] = parseURI(k)
    if not "sec_label" in class_sets[k]: class_sets[k]["sec_label"] = ""

# %%
print ("Found parsed labels", found_lab)
print ("Found external labels", found_sec_lab)
# Out:
# ('Found parsed labels', 9588)
# ('Found external labels', 1146)

# %% [markdown]
# # --------------------
# #### Read in prefix lists and external ontology descriptions (pre-generated)
# # --------------------

# %%
ref_preflist = mfio.load_matrix(final_folder + "network_data/ref-preflist.dat")
ref_obolist = mfio.load_matrix(final_folder + "network_data/ref-oboprefset.dat")

# %%
sort_obolist = sorted({k: len(ref_obolist[k]) for k in ref_obolist}.items(), key=itemgetter(1), reverse=True)
for k in sort_obolist: disAllPrefs[k[0]] = parseURI(k[0]).upper()

# %%
for k in disAllPrefs: print k, disAllPrefs[k]
# Out:
# http://purl.obolibrary.org/obo/INO INO
# http://www.hipaaspace.com/Medical_Billing/Coding/Logical.Observation.Identifiers.Names.and.Codes/ LOINC
# http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl# NCIT
# http://purl.bioontology.org/ontology/NDFRT/ NDFRT
# http://purl.obolibrary.org/obo/UO UO
# http://purl.obolibrary.org/obo/ECO ECO
# http://purl.obolibrary.org/obo/ERO ERO
# http://www.ebi.ac.uk/efo/ EFO
# http://purl.obolibrary.org/obo/comment COMMENT
# http://purl.obolibrary.org/obo/CLO CLO
# http://purl.obolibrary.org/obo/default-relationship-id-prefix DEFAULT RELATIONSHIP ID PREFIX
# http://purl.obolibrary.org/obo/has-role HAS ROLE
# http://www.orpha.net/ORDO/ ORDO
# http://purl.obolibrary.org/obo/idspace IDSPACE
# http://purl.obolibrary.org/obo/BFO BFO
# http://purl.obolibrary.org/obo/DRON DRON
# http://purl.obolibrary.org/obo/TEMP TEMP
# http://bmrbpub.protein.osaka-u.ac.jp/schema/mmcif_nmr-star.owl# BMRB-OWL
# http://purl.obolibrary.org/obo/DIDEO DIDEO
# http://purl.obolibrary.org/obo/CMO CMO
# http://purl.bioontology.org/ontology/UATC/ ATC
# http://purl.org/sig/ont/fma/ FMA
# http://purl.obolibrary.org/obo/is IS
# http://purl.obolibrary.org/obo/PATO PATO
# http://purl.obolibrary.org/obo/MP MP
# http://purl.obolibrary.org/obo/SO SO
# http://purl.obolibrary.org/obo/MS MS
# http://purl.obolibrary.org/obo/GO GO
# http://purl.obolibrary.org/obo/CHEBI CHEBI
# http://purl.obolibrary.org/obo/HP HP
# http://purl.obolibrary.org/obo/TO TO
# http://purl.obolibrary.org/obo/namespace NAMESPACE
# http://purl.obolibrary.org/obo/NCBITaxon NCBI TAXON
# http://purl.obolibrary.org/obo/CL CL
# http://purl.obolibrary.org/obo/transitive TRANSITIVE
# http://rdf.wwpdb.org/schema/pdbx-v42.owl# PDB-OWL
# http://purl.obolibrary.org/obo/OBI OBI
# http://purl.obolibrary.org/obo/EO EO
# http://purl.obolibrary.org/obo/UBPROP UBPROP
# http://semanticscience.org/resource/ SIO-CHEMINF
# http://purl.bioontology.org/ontology/SNOMEDCT/ SNOMEDCT
# http://purl.obolibrary.org/obo/PR PR
# http://www.geneontology.org/formats/oboInOwl# GO-OBO
# http://purl.obolibrary.org/obo/remark REMARK
# http://purl.obolibrary.org/obo/IAO IAO
# http://purl.obolibrary.org/obo/UBERON UBERON
# http://purl.obolibrary.org/obo/BTO BTO
# http://purl.obolibrary.org/obo/date DATE
# http://purl.obolibrary.org/obo/MPIO MPIO
# http://purl.obolibrary.org/obo/PO PO
# http://purl.obolibrary.org/obo/alt ALT
# http://rdf.wwpdb.org/schema/pdbx-v40.owl# PDB-OWL
# http://purl.obolibrary.org/obo/synonymtype SYNONYMTYPE
# http://purl.obolibrary.org/obo/RO RO
# http://purl.obolibrary.org/obo/format-version FORMAT VERSION

# %%
onto_nodes = {}
for k in disAllPrefs:
    if k in ref_obolist: ic_n = ref_obolist[k]
    else: ic_n = ref_preflist[k]
    for m in ic_n:
        if m not in class_sets: continue
        onto_nodes[m] = ontoLabels[k]['name']
print ("Ontology related nodes (only classes)", len(onto_nodes))
# Out:
# ('Ontology related nodes (only classes)', 54639)

# %%
for k in list(onto_nodes.keys())[0:10]: print (k, onto_nodes[k])
# Out:
# ('http://rdf.wwpdb.org/schema/pdbx-v40.owl#symmetryCategory', 'Protein Data Bank Ontology')
# ('http://purl.bioontology.org/ontology/SNOMEDCT/108677001', 'Systematized Nomenclature of Medicine - Clinical Terms')
# ('http://purl.obolibrary.org/obo/CHEBI_8194', 'Chemical Entities of Biological Interest Ontology')
# ('http://purl.obolibrary.org/obo/CHEBI_8196', 'Chemical Entities of Biological Interest Ontology')
# ('http://purl.obolibrary.org/obo/CHEBI_8191', 'Chemical Entities of Biological Interest Ontology')
# ('http://purl.obolibrary.org/obo/CHEBI_116591', 'Chemical Entities of Biological Interest Ontology')
# ('http://purl.obolibrary.org/obo/CHEBI_8199', 'Chemical Entities of Biological Interest Ontology')
# ('http://purl.obolibrary.org/obo/CHEBI_8198', 'Chemical Entities of Biological Interest Ontology')
# ('http://purl.obolibrary.org/obo/CHEBI_116599', 'Chemical Entities of Biological Interest Ontology')
# ('http://purl.bioontology.org/ontology/NDFRT/N0000007050', 'National Drug File - Reference Terminology')

# %%
for k in class_sets:
    if k in onto_nodes: class_sets[k]["FromOntology"] = onto_nodes[k]
    else: class_sets[k]["FromOntology"] = ""

# %% [markdown]
# # --------------------
# #### Read in prefix lists and external vocabulary descriptions (pre-generated)
# # --------------------

# %%
vocab_elem = mfio.load_matrix(final_folder + "network_data/vocab_elem.dat")

# %%
vocab_index = {}
for k in vocab_elem:
    for m in vocab_elem[k]:
        if m not in vocab_index: vocab_index[m] = set([])
        vocab_index[m].add(k)
print ("Terms from vocabularies", len(vocab_index))
# Out:
# ('Terms from vocabularies', 9735)

# %%
sc_nomen = mfio.load_matrix(final_folder + "network_data/sc_nomen.dat")
print ("Vocabularies from LOV", len(sc_nomen))
# Out:
# ('Vocabularies from LOV', 501)

# %%
vocab_nodes = {}
for k in vocab_index:
    st = list(vocab_index[k])[0]
    vocabiden = sc_nomen[st]["vocab_name"].title()
    if not k in onto_nodes:
        if k in class_sets: vocab_nodes[k] = vocabiden
print ("Vocabulary related nodes (only classes)", len(vocab_nodes))
# Out:
# ('Vocabulary related nodes (only classes)', 228)

# %%
for k in class_sets:
    if k in vocab_nodes: class_sets[k]["FromVocabulary"] = vocab_nodes[k]
    else: class_sets[k]["FromVocabulary"] = ""

# %% [markdown]
# # --------------------
# #### Prepare Class-List TSV files
# # --------------------

# %%
uniq_classes = []
for k in class_sets:
    if class_sets[k]["FromOntology"] == "" and class_sets[k]["FromVocabulary"] == "":
        uniq_classes.append(k)
        
print ("Unique non-reused classes", len(uniq_classes))
# Out:
# ('Unique non-reused classes', 2881)

# %%
class_sets_df = pd.DataFrame.from_dict(class_sets, orient="index")
class_sets_df = class_sets_df.reset_index()
del class_sets_df["files"]
class_sets_df = pd.concat([class_sets_df[["index", "refL1", "sec_label", "FromOntology", "FromVocabulary", "dsets"]], 
                           class_sets_df["dsets"].apply(lambda x: len(x.split(":-:"))).to_frame(name="dcount"), 
                           class_sets_df["instance_count"].apply(lambda x: ":-:".join([str(k) for k in x])), 
                           class_sets_df["total_instance_count"]], axis=1)
class_sets_df = class_sets_df.sort_values(["total_instance_count"], ascending=False)
class_sets_df.columns = ["URI", "ParsedLabel", "ExternalLabel", "FromBioOntology", "FromLOVVocabulary", "Datasets", 
                         "DatasetCount", "InstanceCountByDataset", "TotalInstanceCount"]

# %%
print ("Total Classes", class_sets_df.shape[0])
# Out:
# ('Total Classes', 57748)

# %%
class_sets_df.to_csv("final/Extracted_Classes.tsv", sep="\t", index=None)

# %%
class_sets_df.sort_values(["FromLOVVocabulary", "TotalInstanceCount"], ascending=False).head(100)
# Out:
#                                                      URI  \
# 42160             http://www.w3.org/ns/prov#Organization
# 29129            http://www.w3.org/ns/prov#SoftwareAgent
# 43499                    http://www.w3.org/ns/prov#Agent
# 29128                   http://www.w3.org/ns/prov#Person
# 28238        http://vivoweb.org/ontology/core#University
# 36073       http://purl.uniprot.org/core/Structured_Name
# 27658                  http://purl.uniprot.org/core/Gene
# 46557               http://purl.uniprot.org/core/Protein
# 27683              http://purl.uniprot.org/core/Resource
# 36072                http://purl.uniprot.org/core/Strain
# 42582                 http://purl.uniprot.org/core/Taxon
# 38197                  http://purl.uniprot.org/core/Part
# 27651                http://purl.uniprot.org/core/Enzyme
# 29095                 http://www.uniprot.org/core/Tissue
# 36059              http://purl.uniprot.org/core/Database
# 36058              http://purl.uniprot.org/core/Citation
# 36457                  http://www.uniprot.org/core/Taxon
# 27679                  http://purl.uniprot.org/core/Rank
# 29097         http://www.w3.org/2000/01/rdf-schema#Class
# 29100      http://www.w3.org/2000/01/rdf-schema#Resource
# 29098      http://www.w3.org/2000/01/rdf-schema#Datatype
# 29099      http://www.w3.org/2000/01/rdf-schema#Property
# 29096  http://www.w3.org/1999/02/22-rdf-syntax-ns#Sta...
# 40966    http://www.w3.org/1999/02/22-rdf-syntax-ns#List
# 53798  http://www.w3.org/1999/02/22-rdf-syntax-ns#Pro...
# 51528     http://www.w3.org/1999/02/22-rdf-syntax-ns#Seq
# 39918        http://purl.org/net/ohdsi#adrAnnotationBody
# 38194            http://purl.org/net/ohdsi#ADRAnnotation
# 49952            http://purl.org/net/ohdsi#OHDSIMeshTags
# 27633  http://purl.org/net/ohdsi#PubMedDrugHOIAnnotation
# ...                                                  ...
# 46906            http://www.w3.org/2008/05/skos-xl#Label
# 41426        http://www.w3.org/2004/02/skos/core#Concept
# 29119        http://www.w3.org/2004/02/skos/core#concept
# 29117     http://www.w3.org/2004/02/skos/core#Collection
# 29118  http://www.w3.org/2004/02/skos/core#ConceptScheme
# 48255                    http://rdfs.org/ns/void#Linkset
# 54034                    http://rdfs.org/ns/void#Dataset
# 28190         http://rdfs.org/ns/void#DatasetDescription
# 29114            http://www.w3.org/2003/11/swrl#AtomList
# 29115  http://www.w3.org/2003/11/swrl#IndividualPrope...
# 47738  http://www.w3.org/2003/11/swrl#DatavaluedPrope...
# 55706                 http://www.w3.org/2003/11/swrl#Imp
# 29116            http://www.w3.org/2003/11/swrl#Variable
# 28191                             http://schema.org/City
# 28192                             http://schema.org/Drug
# 28193           http://schema.org/DrugPrescriptionStatus
# 28194                     http://schema.org/DrugStrength
# 28195                           http://schema.org/Permit
# 42966                     http://schema.org/Organization
# 36200                         http://schema.org/DrugCost
# 38229                      http://schema.org/MedicalCode
# 48034       http://www.w3.org/2011/content#ContentAsText
# 52997  http://tcga.deri.ie/schema/expression_exon_result
# 36213  http://tcga.deri.ie/schema/expression_gene_result
# 28233  http://tcga.deri.ie/schema/dna_methylation_result
# 28234            http://tcga.deri.ie/schema/miRNA_result
# 41896                 http://tcga.deri.ie/schema/aliquot
# 52504                 http://tcga.deri.ie/schema/analyte
# 28236                http://tcga.deri.ie/schema/protocol
# 28235                 http://tcga.deri.ie/schema/portion
#
#                        ParsedLabel ExternalLabel FromBioOntology  \
# 42160                 Organization
# 29129               Software Agent
# 43499                        Agent
# 29128                       Person
# 28238                   University
# 36073             Structured  Name
# 27658                         Gene
# 46557                      Protein
# 27683                     Resource
# 36072                       Strain
# 42582                        Taxon
# 38197                         Part
# 27651                       Enzyme
# 29095                       Tissue
# 36059                     Database
# 36058                     Citation
# 36457                        Taxon
# 27679                         Rank
# 29097                        Class
# 29100                     Resource
# 29098                     Datatype
# 29099                     Property
# 29096                    Statement
# 40966                         List
# 53798                     Property
# 51528                          Seq
# 39918          Adr Annotation Body
# 38194               Adr Annotation
# 49952              Ohdsi Mesh Tags
# 27633  Pub Med Drug Hoi Annotation
# ...                            ...           ...             ...
# 46906                        Label
# 41426                      Concept
# 29119                      Concept
# 29117                   Collection
# 29118               Concept Scheme
# 48255                      Linkset
# 54034                      Dataset
# 28190          Dataset Description
# 29114                    Atom List
# 29115     Individual Property Atom
# 47738     Datavalued Property Atom
# 55706                          Imp
# 29116                     Variable
# 28191                         City
# 28192                         Drug
# 28193     Drug Prescription Status
# 28194                Drug Strength
# 28195                       Permit
# 42966                 Organization
# 36200                    Drug Cost
# 38229                 Medical Code
# 48034              Content As Text
# 52997       Expression Exon Result
# 36213       Expression Gene Result
# 28233       Dna Methylation Result
# 28234                Mi Rna Result
# 41896                      Aliquot
# 52504                      Analyte
# 28236                     Protocol
# 28235                      Portion
#
#                                  FromLOVVocabulary  \
# 42160                   W3C Provenance Interchange
# 29129                   W3C Provenance Interchange
# 43499                   W3C Provenance Interchange
# 29128                   W3C Provenance Interchange
# 28238                           Vivo Core Ontology
# 36073                        Uniprot Core Ontology
# 27658                        Uniprot Core Ontology
# 46557                        Uniprot Core Ontology
# 27683                        Uniprot Core Ontology
# 36072                        Uniprot Core Ontology
# 42582                        Uniprot Core Ontology
# 38197                        Uniprot Core Ontology
# 27651                        Uniprot Core Ontology
# 29095                        Uniprot Core Ontology
# 36059                        Uniprot Core Ontology
# 36058                        Uniprot Core Ontology
# 36457                        Uniprot Core Ontology
# 27679                        Uniprot Core Ontology
# 29097                    The Rdf Schema Vocabulary
# 29100                    The Rdf Schema Vocabulary
# 29098                    The Rdf Schema Vocabulary
# 29099                    The Rdf Schema Vocabulary
# 29096                  The Rdf Concepts Vocabulary
# 40966                  The Rdf Concepts Vocabulary
# 53798                  The Rdf Concepts Vocabulary
# 51528                  The Rdf Concepts Vocabulary
# 39918                          The P-Plan Ontology
# 38194                          The P-Plan Ontology
# 49952                          The P-Plan Ontology
# 27633                          The P-Plan Ontology
# ...                                            ...
# 46906                    Skos Extension For Labels
# 41426         Simple Knowledge Organization System
# 29119         Simple Knowledge Organization System
# 29117         Simple Knowledge Organization System
# 29118         Simple Knowledge Organization System
# 48255  Semantically-Interlinked Online Communities
# 54034  Semantically-Interlinked Online Communities
# 28190  Semantically-Interlinked Online Communities
# 29114                   Semantic Web Rule Language
# 29115                   Semantic Web Rule Language
# 47738                   Semantic Web Rule Language
# 55706                   Semantic Web Rule Language
# 29116                   Semantic Web Rule Language
# 28191                        Schema.Org Vocabulary
# 28192                        Schema.Org Vocabulary
# 28193                        Schema.Org Vocabulary
# 28194                        Schema.Org Vocabulary
# 28195                        Schema.Org Vocabulary
# 42966                        Schema.Org Vocabulary
# 36200                        Schema.Org Vocabulary
# 38229                        Schema.Org Vocabulary
# 48034                  Representing Content In Rdf
# 52997       Renewable Energy And Energy Efficiency
# 36213       Renewable Energy And Energy Efficiency
# 28233       Renewable Energy And Energy Efficiency
# 28234       Renewable Energy And Energy Efficiency
# 41896       Renewable Energy And Energy Efficiency
# 52504       Renewable Energy And Energy Efficiency
# 28236       Renewable Energy And Energy Efficiency
# 28235       Renewable Energy And Energy Efficiency
#
#                                                 Datasets  DatasetCount  \
# 42160                                        :-:DisGenet             2
# 29129                                        :-:DisGenet             2
# 43499                                        :-:DisGenet             2
# 29128                                               NBDC             1
# 28238                                        linkeddrugs             1
# 36073               EBI-UniProt:-:Linkedlifedata-Uniprot             2
# 27658               EBI-UniProt:-:Linkedlifedata-Uniprot             2
# 46557               EBI-UniProt:-:Linkedlifedata-Uniprot             2
# 27683                                        EBI-UniProt             1
# 36072                                 EBI-UniProt:-:NBDC             2
# 42582  :-:EBI-UniProt:-:DisGenet:-:Linkedlifedata-Uni...             4
# 38197               EBI-UniProt:-:Linkedlifedata-Uniprot             2
# 27651                                        EBI-UniProt             1
# 29095                                               NBDC             1
# 36059                                 EBI-UniProt:-:NBDC             2
# 36058                                        EBI-UniProt             1
# 36457                                               NBDC             1
# 27679                                 EBI-UniProt:-:NBDC             2
# 29097  Linkedlifedata-Pubmed:-:ModelOrganism:-:EBI-Bi...            21
# 29100  Bio2Rdf-Dbsnp:-::-:Bio2Rdf-Homologene:-:Bio2Rd...             8
# 29098  EBI-Chembl:-:LinkedSPL:-:EBI-UniProt:-:SBG-CCL...             9
# 29099                                               NBDC             1
# 29096                                 EBI-UniProt:-:NBDC             2
# 40966  Linkedlifedata-Mint:-:Linkedlifedata-Intact:-:...             9
# 53798  Linkedlifedata-Pubmed:-:Linkedlifedata-Drugban...            27
# 51528                                               NBDC             1
# 39918                                  LinkedSPL:-:OHDSI             2
# 38194                                  LinkedSPL:-:OHDSI             2
# 49952                                  LinkedSPL:-:OHDSI             2
# 27633                                  LinkedSPL:-:OHDSI             2
# ...                                                  ...           ...
# 46906        Linkedlifedata-Rxnorm:-:Linkedlifedata-Umls             2
# 41426  Linkedlifedata-Symptom:-:Linkedlifedata-Phenot...            10
# 29119                                  Pubchem:-:Pubchem             2
# 29117                                       WikiPathways             1
# 29118  Linkedlifedata-Symptom:-:Linkedlifedata-Phenot...             8
# 48255                    :-:EBI-Chembl:-:DisGenet:-:NBDC             4
# 54034  EBI-BioModels:-::-:EBI-Chembl:-:Mesh:-:WikiPat...            10
# 28190  EBI-BioModels:-::-:EBI-Chembl:-:Mesh:-:WikiPat...             8
# 29114                                          LinkedSPL             1
# 29115                                          LinkedSPL             1
# 47738                                          LinkedSPL             1
# 55706                                          LinkedSPL             1
# 29116                                          LinkedSPL             1
# 28191                                        linkeddrugs             1
# 28192                                        linkeddrugs             1
# 28193                                        linkeddrugs             1
# 28194                                        linkeddrugs             1
# 28195                                        linkeddrugs             1
# 42966                                        linkeddrugs             1
# 36200                                        linkeddrugs             1
# 38229                                        linkeddrugs             1
# 48034                                          LinkedSPL             1
# 52997                                         LinkedTCGA             1
# 36213                                         LinkedTCGA             1
# 28233                                         LinkedTCGA             1
# 28234                                         LinkedTCGA             1
# 41896                                         LinkedTCGA             1
# 52504                                         LinkedTCGA             1
# 28236                                         LinkedTCGA             1
# 28235                                         LinkedTCGA             1
#
#                                   InstanceCountByDataset  TotalInstanceCount
# 42160                                             9:-:41                  50
# 29129                                              3:-:9                  12
# 43499                                              1:-:6                   7
# 29128                                                  6                   6
# 28238                                                  8                   8
# 36073                                486920183:-:2061023           488981206
# 27658                               426809488:-:23269980           450079468
# 46557                                154494281:-:6955988           161450269
# 27683                                           93596295            93596295
# 36072                                     81149055:-:371            81149426
# 42582                          1:-:1830516:-:1:-:1130281             2960799
# 38197                                      411162:-:5552              416714
# 27651                                               7451                7451
# 29095                                                215                 215
# 36059                                            162:-:3                 165
# 36058                                                152                 152
# 36457                                                 38                  38
# 27679                                             28:-:1                  29
# 29097  11:-:56:-:15:-:4:-:169:-:169:-:169:-:15:-:39:-...                1438
# 29100                6:-:380:-:5:-:19:-:6:-:12:-:4:-:386                 818
# 29098                7:-:9:-:5:-:1:-:0:-:3:-:6:-:117:-:5                 153
# 29099                                                  1                   1
# 29096                                  1204805539:-:2354          1204807893
# 40966         28:-:28:-:28:-:28:-:5:-:28:-:3188:-:5:-:28                3366
# 53798  54:-:23:-:28:-:170:-:98:-:26:-:28:-:28:-:264:-...                3008
# 51528                                                  2                   2
# 39918                                  1505614:-:3369746             4875360
# 38194                                    61077:-:2162409             2223486
# 49952                                    214853:-:392955              607808
# 27633                                    106341:-:199532              305873
# ...                                                  ...                 ...
# 46906                                   834019:-:4336173             5170192
# 41426  935:-:9947:-:8671:-:38363:-:268628:-:2091712:-...             2513288
# 29119                                        6008:-:6008               12016
# 29117                                               1841                1841
# 29118                     1:-:1:-:1:-:1:-:10:-:1:-:2:-:2                  19
# 48255                                   1:-:3:-:30:-:118                 152
# 54034          1:-:15:-:17:-:1:-:1:-:1:-:0:-:2:-:33:-:73                 144
# 28190                      1:-:1:-:1:-:1:-:1:-:1:-:1:-:3                  10
# 29114                                                 66                  66
# 29115                                                 56                  56
# 47738                                                 32                  32
# 55706                                                 24                  24
# 29116                                                 24                  24
# 28191                                                 35                  35
# 28192                                                  0                   0
# 28193                                                  0                   0
# 28194                                                  0                   0
# 28195                                                  0                   0
# 42966                                                  0                   0
# 36200                                                  0                   0
# 38229                                                  0                   0
# 48034                                                 19                  19
# 52997                                            3350508             3350508
# 36213                                             287266              287266
# 28233                                              39998               39998
# 28234                                              17680               17680
# 41896                                               2913                2913
# 52504                                               1425                1425
# 28236                                               1425                1425
# 28235                                                585                 585
#
# [100 rows x 9 columns]

# %% [markdown]
# # --------------------
# #### Read Instances
# # --------------------

# %%
def get_folder_path(dset):
    folder_path = final_folder + "instance_data/"
    if "bio2rdf" in dset.lower():
        subdir = os.listdir(folder_path + "Bio2Rdf/")
        if dset in subdir: return folder_path + "Bio2Rdf/" + dset + "/"
        else: return folder_path + "Bio2Rdf/Bio2Rdf/"
    elif "EBI" in dset:
        return folder_path + "EBI/" + dset + "/"
    elif "sbg" in dset.lower():
        return folder_path + "SBG/" + dset + "/"
    elif "nbdc" in dset.lower():
        return folder_path + "NBDC/"
    elif "linkedlifedata" in dset.lower():
        return folder_path + "Linkedlifedata/" + dset + "/"
    elif "modelorganism" in dset.lower():
        return folder_path + "ModelOrganism/"
    else:
        return folder_path + dset + "/"
    
def get_inst_data(dset, verbose=True):
    str_inst_val = True
    num_inst_val = True
    if len(dset) == 0: 
        return None, None, False, False
    folder_path = get_folder_path(dset)
    if verbose: print ("---------------------------------")
    if verbose: print (dset, folder_path)
    if os.path.isdir(folder_path):
        str_inst = pd.read_csv(folder_path + "str_inst_df.tsv", sep="\t")
        num_inst = pd.read_csv(folder_path + "num_inst_df.tsv", sep="\t")
        if verbose: print ("Dset sizes", str_inst.shape, num_inst.shape)
        if str_inst.shape[0] == 0: str_inst_val = False
        if num_inst.shape[0] == 0: num_inst_val = False
        return str_inst, num_inst, str_inst_val, num_inst_val
    else: 
        print ("No folder path found -  XXX")
        return None, None, None, None

# %%
str_inst, num_inst, _, _ = get_inst_data("Bio2Rdf-Drugbank")
str_inst[str_inst['ftype'] == 'entity'].sample(10)
# Out:
# ---------------------------------
# ('Bio2Rdf-Drugbank', 'final/raw_data_folder/instance_data/Bio2Rdf/Bio2Rdf/')
# ('Dset sizes', (8919, 13), (436, 13))
#                                                   index is_categorical dtype  \
# 606   http://bio2rdf.org/clinicaltrials_vocabulary:G...          False   iri
# 124                      http://bio2rdf.org/apo:0000187          False   iri
# 7009  http://bio2rdf.org/pharmgkb_vocabulary:variant...          False   iri
# 8186          http://bio2rdf.org/vz_vocabulary:Resource          False   iri
# 7083   http://bio2rdf.org/pseudocap_vocabulary:Resource          False   iri
# 5312     http://bio2rdf.org/mirbase_vocabulary:Resource          False   iri
# 7171        http://bio2rdf.org/rgap_vocabulary:Resource          False   iri
# 4233             http://bio2rdf.org/mgi_vocabulary:Gene          False   iri
# 628   http://bio2rdf.org/clinicaltrials_vocabulary:I...          False   iri
# 2557     http://bio2rdf.org/genbank_vocabulary:Resource          False   iri
#
#       lenmedian  uniq_set           file  inst_count origdtype  \
# 606        75.0      1279  inst_5247.tsv        1279    object
# 124        64.0      2000  inst_3441.tsv        2000    object
# 7009       41.5      2000  inst_2340.tsv        2000    object
# 8186       25.5       105   inst_739.tsv         105    object
# 7083       35.0      2000  inst_8981.tsv        2000    object
# 5312       38.5      2000  inst_3249.tsv        2000    object
# 7171       41.0      2000  inst_7268.tsv        2000    object
# 4233       29.0      2000   inst_393.tsv        2000    object
# 628        75.0      2000  inst_1375.tsv        2000    object
# 2557       37.5      2000  inst_1456.tsv        2000    object
#
#                                               namespace   ftype categories  \
# 606   set(['http://bio2rdf.org/clinicaltrials_resour...  entity    set([])
# 124           set(['http://bio2rdf.org/sgd_resource:'])  entity    set([])
# 7009     set(['http://bio2rdf.org/pharmgkb_resource:'])  entity    set([])
# 8186                    set(['http://bio2rdf.org/vz:'])  entity    set([])
# 7083             set(['http://bio2rdf.org/pseudocap:'])  entity    set([])
# 5312               set(['http://bio2rdf.org/mirbase:'])  entity    set([])
# 7171                  set(['http://bio2rdf.org/rgap:'])  entity    set([])
# 4233                   set(['http://bio2rdf.org/mgi:'])  entity    set([])
# 628   set(['http://bio2rdf.org/clinicaltrials_resour...  entity    set([])
# 2557               set(['http://bio2rdf.org/genbank:'])  entity    set([])
#
#                                              samp_insts    lenstd
# 606   ['http://bio2rdf.org/clinicaltrials_resource:d...  0.000000
# 124   ['http://bio2rdf.org/sgd_resource:ce1f627a35c4...  0.000000
# 7009  ['http://bio2rdf.org/pharmgkb_resource:19197',...  0.500000
# 8186  ['http://bio2rdf.org/vz:804', 'http://bio2rdf....  0.500000
# 7083  ['http://bio2rdf.org/pseudocap:PA0225', 'http:...  0.000000
# 5312  ['http://bio2rdf.org/mirbase:MI0016863', 'http...  1.707825
# 7171  ['http://bio2rdf.org/rgap:LOC_Os05g23610.1', '...  2.160247
# 4233  ['http://bio2rdf.org/mgi:5434473', 'http://bio...  0.816497
# 628   ['http://bio2rdf.org/clinicaltrials_resource:1...  0.000000
# 2557  ['http://bio2rdf.org/genbank:AAHY01001988.1', ...  2.165064

# %% [markdown]
# # --------------------
# #### Extract Property Data from CODP-Combined Network
# # --------------------

# %%
def get_new_dsets(node):
    src_dsets = combG.node[node]["dsets"] if "dsets" in combG.node[node] else ""
    src_dsets = [old_dset_mappings[k] for k in src_dsets.split(":-:") if k in old_dset_mappings]
    return src_dsets

def get_assoc_properties(source, dset):
    data_properties = []
    obj_properties = []
    def_l_set = 'http://www.w3.org/2001/XMLSchema#string'
    if not combG.has_node(source): return ([], [])
    src_dsets = get_new_dsets(source)
    #print (src_dsets)
    if "NBDC" in dset: dset = "NBDC"
    elif "ModelOrganism" in dset: dset = "ModelOrganism"
    else: dset = dset
    for k in combG[source]:
        dprop_material = set([])
        oprop_material = set([])
        if combG.node[k]["type"] == "literal" or combG.node[k]["type"] == "objectProp":
            targ_dsets = get_new_dsets(k)
            dset_intersection = set(src_dsets).intersection(set(targ_dsets))
            if dset in dset_intersection:
                for n in combG[source][k]:
                    mat = combG[source][k][n]
                    _type = mat['type'] if 'type' in mat else def_l_set
                    _count = mat['count'] if 'count' in mat else 0
                    if len(_type.split("->")) == 1: 
                        dprop_material.add((_count, _type))
                    else:
                        oprop_material.add((_count, _type))
                if len(dprop_material) > 0: 
                    data_properties.append((k, dprop_material))
                if len(oprop_material) > 0:
                    obj_properties.append((k, oprop_material))
    return (data_properties, obj_properties)

def get_labels(node):
    parsed_label = combG.node[node]["refL1"] if "refL1" in combG.node[node] else parseURI(node)
    sec_label = combG.node[node]["sec_label"] if "sec_label" in combG.node[node] else ""
    return parsed_label, sec_label

def prepare_property_dtype_dict(dset):
    curop = {}
    curdp = {}
    dtypes = set([])
    opn_c = 0
    dpn_c = 0
    for m in all_dsets[dset]['Classes']:
        dprop, oprop = get_assoc_properties(m, dset)
        for item in oprop:
            n = item[0]
            mn = item[1]
            if not n in curop: curop[n] = {"Realizations": {}}
            parsed_label, sec_label = get_labels(n)
            curop[n]["ParsedLabel"] = parsed_label
            curop[n]["ExternalLabel"] = sec_label
            curop[n]["Shared Datasets"] = get_new_dsets(n)
            if n in oproponto_nodes: curop[n]["FromBioOntology"] = oproponto_nodes[n]
            else: curop[n]["FromBioOntology"] = ""
            if n in opropvocab_nodes: curop[n]["FromLOVVocabulary"] = opropvocab_nodes[n]
            else: curop[n]["FromLOVVocabulary"] = ""
            for op in mn:
                opd = op[1].split("->")
                _domain = m
                _range = opd[2] if len(opd) > 2 else ""
                _count = op[0]
                pdict = {"Domain": _domain, "Range": _range, "Assertion Count": _count}
                curop[n]["Realizations"][op[1]] = pdict
                opn_c += 1
        for item in dprop:
            n = item[0]
            mn = item[1]
            if not n in curdp: curdp[n] = {"Realizations": {}}
            parsed_label, sec_label = get_labels(n)
            curdp[n]["ParsedLabel"] = parsed_label
            curdp[n]["ExternalLabel"] = sec_label
            curdp[n]["Shared Datasets"] = get_new_dsets(n)
            if n in dproponto_nodes: curdp[n]["FromBioOntology"] = dproponto_nodes[n]
            else: curdp[n]["FromBioOntology"] = ""
            if n in dpropvocab_nodes: curdp[n]["FromLOVVocabulary"] = dpropvocab_nodes[n]
            else: curdp[n]["FromLOVVocabulary"] = ""
            for dp in mn:
                _range = dp[1]
                _count = dp[0]
                dtypes.add(_range)
                try:
                    realization = m + "->" + n + "->" + _range
                    pdict = {"Domain": m, "Range": _range, "Assertion Count": _count}
                    curdp[n]["Realizations"][realization] = pdict
                    dpn_c += 1
                except: 
                    print ("Error generating realization for", dp, n, m)
    dtypes = list(dtypes)
    return curop, curdp, dtypes, opn_c, dpn_c

# %%
dproperty_sets = {}
oproperty_sets = {}
for k in combG.nodes():
    if not "type" in combG.node[k]: continue
    if combG.node[k]["type"] == 'literal': dproperty_sets[k] = {}
    if combG.node[k]["type"] == 'objectProp': oproperty_sets[k] = {}

print ("Object Properties", len(oproperty_sets))
print ("Data Properties", len(dproperty_sets))
# Out:
# ('Object Properties', 4397)
# ('Data Properties', 8447)

# %%
oproponto_nodes = {}
dproponto_nodes = {}
for k in disAllPrefs:
    if k in ref_obolist: ic_n = ref_obolist[k]
    else: ic_n = ref_preflist[k]
    for m in ic_n:
        if m in oproperty_sets:
            oproponto_nodes[m] = ontoLabels[k]['name']
        elif m in dproperty_sets:
            dproponto_nodes[m] = ontoLabels[k]['name']
print ("Ontology related nodes (only object properties)", len(oproponto_nodes))
print ("Ontology related nodes (only data properties)", len(dproponto_nodes))
# Out:
# ('Ontology related nodes (only object properties)', 1514)
# ('Ontology related nodes (only data properties)', 6005)

# %%
for k in list(oproponto_nodes.keys())[0:10]: print (k, oproponto_nodes[k])
# Out:
# (u'http://bmrbpub.protein.osaka-u.ac.jp/schema/mmcif_nmr-star.owl#has_cross_correlation_d_csa_experimentCategory', 'Biological Magnetic Resonance Bank Ontology')
# (u'http://rdf.wwpdb.org/schema/pdbx-v42.owl#has_pdbx_nmr_spectrometerCategory', 'Protein Data Bank Ontology')
# (u'http://bmrbpub.protein.osaka-u.ac.jp/schema/mmcif_nmr-star.owl#has_entity_purity_list', 'Biological Magnetic Resonance Bank Ontology')
# (u'http://bmrbpub.protein.osaka-u.ac.jp/schema/mmcif_nmr-star.owl#has_chem_shift_anisotropy', 'Biological Magnetic Resonance Bank Ontology')
# (u'http://rdf.wwpdb.org/schema/pdbx-v42.owl#has_computing', 'Protein Data Bank Ontology')
# (u'http://rdf.wwpdb.org/schema/pdbx-v42.owl#has_em_virus_entity', 'Protein Data Bank Ontology')
# (u'http://bmrbpub.protein.osaka-u.ac.jp/schema/mmcif_nmr-star.owl#has_entity_natural_srcCategory', 'Biological Magnetic Resonance Bank Ontology')
# (u'http://rdf.wwpdb.org/schema/pdbx-v42.owl#has_atom_typeCategory', 'Protein Data Bank Ontology')
# (u'http://bmrbpub.protein.osaka-u.ac.jp/schema/mmcif_nmr-star.owl#has_assemblyCategory', 'Biological Magnetic Resonance Bank Ontology')
# (u'http://rdf.wwpdb.org/schema/pdbx-v42.owl#has_em_sample_preparation', 'Protein Data Bank Ontology')

# %%
opropvocab_nodes = {}
dpropvocab_nodes = {}
for k in vocab_index:
    st = list(vocab_index[k])[0]
    vocabiden = sc_nomen[st]["vocab_name"].title()
    if not k in oproponto_nodes:
        if k in oproperty_sets: opropvocab_nodes[k] = vocabiden
    if not k in dproponto_nodes:
        if k in dproperty_sets: dpropvocab_nodes[k] = vocabiden
print ("Vocabulary related nodes (only object properties)", len(opropvocab_nodes))
print ("Vocabulary related nodes (only data properties)", len(dpropvocab_nodes))
# Out:
# ('Vocabulary related nodes (only object properties)', 345)
# ('Vocabulary related nodes (only data properties)', 716)

# %%
res_n = 'http://rdf.wwpdb.org/schema/pdbx-v40.owl#atom_sites'
dprop2, oprop2 = get_assoc_properties(res_n, "NBDC-PDB")
res_n = 'http://bio2rdf.org/drugbank_vocabulary:Drug'
dprop1, oprop1 = get_assoc_properties(res_n, "Bio2Rdf-Drugbank")

for k in oprop2:
    print ("--------------------")
    print (k[0])
    for m in k[1]: print (m)
# Out:
# --------------------
# http://rdf.wwpdb.org/schema/pdbx-v40.owl#reference_to_entry
# (108526, u'http://rdf.wwpdb.org/schema/pdbx-v40.owl#atom_sites->http://rdf.wwpdb.org/schema/pdbx-v40.owl#reference_to_entry->http://rdf.wwpdb.org/schema/pdbx-v40.owl#entry')
# --------------------
# http://rdf.wwpdb.org/schema/pdbx-v40.owl#of_datablock
# (108526, u'http://rdf.wwpdb.org/schema/pdbx-v40.owl#atom_sites->http://rdf.wwpdb.org/schema/pdbx-v40.owl#of_datablock->http://rdf.wwpdb.org/schema/pdbx-v40.owl#datablock')

# %% [markdown]
# # --------------------
# #### Prepare Final Dataset
# # --------------------

# %%
all_dsets = {}
for k in set(class_sets_df["Datasets"]):
    ap = k.split(":-:")
    for m in ap: 
        if not m in all_dsets: 
            all_dsets[m] = {"SPARQL Endpoint": get_sparql_endpoint(m), 
                            "Counts": {
                                "Class Count": 0,
                                "Object Property Count": 0,
                                "Data Property Count": 0,
                                "Datatypes Count": 0,
                                "Object Property Realization Count": 0,
                                "Data Property Realization Count": 0,
                                "Class-with-Instance Count": 0,
                                "Object Property-with-Assertion Count": 0,
                                "Data Property-with-Assertion Count": 0
                            },
                            "Classes": {},
                            "Properties": {
                                "Object Properties": {},
                                "Data Properties": {}
                            },
                            "Datatypes": []
                           }
    
print ("Total Datasets", len(all_dsets))
# Out:
# ('Total Datasets', 100)

# %%
for k in class_sets:
    dsets_c = class_sets[k]['dsets'].split(":-:")
    instances = class_sets[k]['instance_count']
    for m in range(len(dsets_c)):
        class_dict = {"URI": k, 
                      "Parsed Label": class_sets[k]["refL1"], 
                      "External Label": class_sets[k]["sec_label"], 
                      "Shared Datasets": class_sets[k]["dsets"].split(":-:"), 
                      "Source BioPortal Ontology": class_sets[k]["FromOntology"],
                      "Source LOV Vocabulary": class_sets[k]["FromVocabulary"],
                      "Instance Count": instances[m], 
                      "Instance Characteristics": {}}
        all_dsets[dsets_c[m]]['Classes'][k] = class_dict
        all_dsets[dsets_c[m]]["Counts"]['Class Count'] += 1

# %%
for k in all_dsets:
    str_inst, num_inst, str_valid, num_valid = get_inst_data(k)
    data_count = 0
    if str_valid:
        entity_data = str_inst[str_inst['ftype'] == 'entity']
        entity_data = entity_data.set_index("index").to_dict(orient="index")
        for m in entity_data:
            if m in all_dsets[k]['Classes']:
                instance_dict = {"Sample Instances (3)": eval(entity_data[m]['samp_insts']), 
                                 "Namespaces": list(eval(entity_data[m]['namespace'])), 
                                 "Is Categorical": entity_data[m]['is_categorical'], 
                                 "Sample Instances Total": entity_data[m]['inst_count'], 
                                 'Categories': list(eval(entity_data[m]['categories'])), 
                                 'Datatype': entity_data[m]['dtype'], 
                                 'Instance Length (Median)': entity_data[m]['lenmedian'], 
                                 'Instance Length (Standard Deviation)': entity_data[m]['lenstd'], 
                                 'Is String': True}
                all_dsets[k]['Classes'][m]["Instance Characteristics"] = instance_dict
                all_dsets[k]["Counts"]["Class-with-Instance Count"] += 1
# Out:
# ---------------------------------
# ('ModelOrganism-Flymine', 'final/raw_data_folder/instance_data/ModelOrganism/')
# ('Dset sizes', (6317, 13), (91, 13))
# ---------------------------------
# ('Pubchem', 'final/raw_data_folder/instance_data/Pubchem/')
# ('Dset sizes', (42837, 13), (35, 13))
# ---------------------------------
# ('Bio2Rdf-Mesh', 'final/raw_data_folder/instance_data/Bio2Rdf/Bio2Rdf/')
# ('Dset sizes', (8919, 13), (436, 13))
# ---------------------------------
# ('NBDC-BMRB', 'final/raw_data_folder/instance_data/NBDC/')
# ('Dset sizes', (33143, 13), (4277, 13))
# ---------------------------------
# ('Bio2Rdf-Interpro', 'final/raw_data_folder/instance_data/Bio2Rdf/Bio2Rdf-Interpro/')
# ('Dset sizes', (393, 13), (2, 13))
# ---------------------------------
# ('Bio2Rdf-Sider', 'final/raw_data_folder/instance_data/Bio2Rdf/Bio2Rdf/')
# ('Dset sizes', (8919, 13), (436, 13))
# ---------------------------------
# ('Linkedlifedata-Mint', 'final/raw_data_folder/instance_data/Linkedlifedata/Linkedlifedata-Mint/')
# ('Dset sizes', (129, 13), (5, 13))
# ---------------------------------
# ('EBI-Reactome', 'final/raw_data_folder/instance_data/EBI/EBI-Reactome/')
# ('Dset sizes', (278, 13), (9, 13))
# ---------------------------------
# ('Linkedlifedata-Pubmed', 'final/raw_data_folder/instance_data/Linkedlifedata/Linkedlifedata-Pubmed/')
# ('Dset sizes', (23, 13), (0, 1))
# ---------------------------------
# ('Bio2Rdf-Sgd', 'final/raw_data_folder/instance_data/Bio2Rdf/Bio2Rdf/')
# ('Dset sizes', (8919, 13), (436, 13))
# ---------------------------------
# ('WikiPathways', 'final/raw_data_folder/instance_data/WikiPathways/')
# ('Dset sizes', (293, 13), (41, 13))
# ---------------------------------
# ('Bio2Rdf-Omim', 'final/raw_data_folder/instance_data/Bio2Rdf/Bio2Rdf/')
# ('Dset sizes', (8919, 13), (436, 13))
# ---------------------------------
# ('Bio2Rdf-Dbsnp', 'final/raw_data_folder/instance_data/Bio2Rdf/Bio2Rdf-Dbsnp/')
# ('Dset sizes', (205, 13), (19, 13))
# ---------------------------------
# ('Bio2Rdf-Hgnc', 'final/raw_data_folder/instance_data/Bio2Rdf/Bio2Rdf/')
# ('Dset sizes', (8919, 13), (436, 13))
# ---------------------------------
# ('Bio2Rdf-Ndc', 'final/raw_data_folder/instance_data/Bio2Rdf/Bio2Rdf/')
# ('Dset sizes', (8919, 13), (436, 13))
# ---------------------------------
# ('ModelOrganism-Mousemine', 'final/raw_data_folder/instance_data/ModelOrganism/')
# ('Dset sizes', (6317, 13), (91, 13))
# ---------------------------------
# ('Linkedlifedata-Symptom', 'final/raw_data_folder/instance_data/Linkedlifedata/Linkedlifedata-Symptom/')
# ('Dset sizes', (117, 13), (0, 1))
# ---------------------------------
# ('ModelOrganism-Zebrafishmine', 'final/raw_data_folder/instance_data/ModelOrganism/')
# ('Dset sizes', (6317, 13), (91, 13))
# ---------------------------------
# ('NBDC-INSDC', 'final/raw_data_folder/instance_data/NBDC/')
# ('Dset sizes', (33143, 13), (4277, 13))
# ---------------------------------
# ('Bio2Rdf-Ncbigene', 'final/raw_data_folder/instance_data/Bio2Rdf/Bio2Rdf/')
# ('Dset sizes', (8919, 13), (436, 13))
# ---------------------------------
# ('Bio2Rdf-Lsr', 'final/raw_data_folder/instance_data/Bio2Rdf/Bio2Rdf/')
# ('Dset sizes', (8919, 13), (436, 13))
# ---------------------------------
# ('Linkedlifedata-Umls', 'final/raw_data_folder/instance_data/Linkedlifedata/Linkedlifedata-Umls/')
# ('Dset sizes', (1292, 13), (0, 1))
# ---------------------------------
# ('Bio2Rdf-Pharmgkb', 'final/raw_data_folder/instance_data/Bio2Rdf/Bio2Rdf/')
# ('Dset sizes', (8919, 13), (436, 13))
# ---------------------------------
# ('Linkedlifedata-Drugbank', 'final/raw_data_folder/instance_data/Linkedlifedata/Linkedlifedata-Drugbank/')
# ('Dset sizes', (174, 13), (19, 13))
# ---------------------------------
# ('ModelOrganism', 'final/raw_data_folder/instance_data/ModelOrganism/')
# ('Dset sizes', (6317, 13), (91, 13))
# ---------------------------------
# ('NBDC-Quanto', 'final/raw_data_folder/instance_data/NBDC/')
# ('Dset sizes', (33143, 13), (4277, 13))
# ---------------------------------
# ('Linkedlifedata-Pfam-B', 'final/raw_data_folder/instance_data/Linkedlifedata/Linkedlifedata-Pfam-B/')
# ('Dset sizes', (19, 13), (1, 13))
# ---------------------------------
# ('NBDC-TG-GATE', 'final/raw_data_folder/instance_data/NBDC/')
# ('Dset sizes', (33143, 13), (4277, 13))
# ---------------------------------
# ('NBDC-Glytoucan', 'final/raw_data_folder/instance_data/NBDC/')
# ('Dset sizes', (33143, 13), (4277, 13))
# ---------------------------------
# ('NBDC-JCM', 'final/raw_data_folder/instance_data/NBDC/')
# ('Dset sizes', (33143, 13), (4277, 13))
# ---------------------------------
# ('LinkedSPL', 'final/raw_data_folder/instance_data/LinkedSPL/')
# ('Dset sizes', (1010, 13), (39, 13))
# ---------------------------------
# ('linkeddrugs', 'final/raw_data_folder/instance_data/linkeddrugs/')
# ('Dset sizes', (20739, 13), (204, 13))
# ---------------------------------
# ('PathwayCommons', 'final/raw_data_folder/instance_data/PathwayCommons/')
# ('Dset sizes', (586, 13), (20, 13))
# ---------------------------------
# ('NBDC-PDB', 'final/raw_data_folder/instance_data/NBDC/')
# ('Dset sizes', (33143, 13), (4277, 13))
# ---------------------------------
# ('Linkedlifedata-Chembl', 'final/raw_data_folder/instance_data/Linkedlifedata/Linkedlifedata-Chembl/')
# ('Dset sizes', (142, 13), (11, 13))
# ---------------------------------
# ('Bio2Rdf-Ctd', 'final/raw_data_folder/instance_data/Bio2Rdf/Bio2Rdf/')
# ('Dset sizes', (8919, 13), (436, 13))
# ---------------------------------
# ('LinkedTCGA', 'final/raw_data_folder/instance_data/LinkedTCGA/')
# ('Dset sizes', (157, 13), (63, 13))
# ---------------------------------
# ('Linkedlifedata-Homologene', 'final/raw_data_folder/instance_data/Linkedlifedata/Linkedlifedata-Homologene/')
# ('Dset sizes', (19, 13), (14, 13))
# ---------------------------------
# ('NBDC-ICGC', 'final/raw_data_folder/instance_data/NBDC/')
# ('Dset sizes', (33143, 13), (4277, 13))
# ---------------------------------
# ('NBDC-Refex', 'final/raw_data_folder/instance_data/NBDC/')
# ('Dset sizes', (33143, 13), (4277, 13))
# ---------------------------------
# ('ModelOrganism-Humanmine', 'final/raw_data_folder/instance_data/ModelOrganism/')
# ('Dset sizes', (6317, 13), (91, 13))
# ---------------------------------
# ('Linkedlifedata-Dailymed', 'final/raw_data_folder/instance_data/Linkedlifedata/Linkedlifedata-Dailymed/')
# ('Dset sizes', (47, 13), (0, 1))
# ---------------------------------
# ('Linkedlifedata-Clinicaltrials', 'final/raw_data_folder/instance_data/Linkedlifedata/Linkedlifedata-Clinicaltrials/')
# ('Dset sizes', (160, 13), (6, 13))
# ---------------------------------
# ('Linkedlifedata-Diseasome', 'final/raw_data_folder/instance_data/Linkedlifedata/Linkedlifedata-Diseasome/')
# ('Dset sizes', (24, 13), (3, 13))
# ---------------------------------
# ('Linkedlifedata-Pfam', 'final/raw_data_folder/instance_data/Linkedlifedata/Linkedlifedata-Pfam/')
# ('Dset sizes', (30, 13), (1, 13))
# ---------------------------------
# ('NBDC', 'final/raw_data_folder/instance_data/NBDC/')
# ('Dset sizes', (33143, 13), (4277, 13))
# ---------------------------------
# ('SBG-TCGA', 'final/raw_data_folder/instance_data/SBG/SBG-TCGA/')
# ('Dset sizes', (367, 13), (27, 13))
# ---------------------------------
# ('Linkedlifedata-Phenotype', 'final/raw_data_folder/instance_data/Linkedlifedata/Linkedlifedata-Phenotype/')
# ('Dset sizes', (119, 13), (0, 1))
# ---------------------------------
# ('NBDC-Orth', 'final/raw_data_folder/instance_data/NBDC/')
# ('Dset sizes', (33143, 13), (4277, 13))
# ---------------------------------
# ('Linkedlifedata-Intact', 'final/raw_data_folder/instance_data/Linkedlifedata/Linkedlifedata-Intact/')
# ('Dset sizes', (161, 13), (6, 13))
# ---------------------------------
# ('Bio2Rdf-Medline', 'final/raw_data_folder/instance_data/Bio2Rdf/Bio2Rdf-Medline/')
# ('Dset sizes', (256, 13), (10, 13))
# ---------------------------------
# ('NBDC-MBGD', 'final/raw_data_folder/instance_data/NBDC/')
# ('Dset sizes', (33143, 13), (4277, 13))
# ---------------------------------
# ('NBDC-GGDONTO', 'final/raw_data_folder/instance_data/NBDC/')
# ('Dset sizes', (33143, 13), (4277, 13))
# ---------------------------------
# ('Bio2Rdf-Mgi', 'final/raw_data_folder/instance_data/Bio2Rdf/Bio2Rdf/')
# ('Dset sizes', (8919, 13), (436, 13))
# ---------------------------------
# ('Bio2Rdf-Refseq', 'final/raw_data_folder/instance_data/Bio2Rdf/Bio2Rdf-Refseq/')
# ('Dset sizes', (330, 13), (18, 13))
# ---------------------------------
# ('Mesh', 'final/raw_data_folder/instance_data/Mesh/')
# ('Dset sizes', (241, 13), (12, 13))
# ---------------------------------
# ('NBDC-Famsbase', 'final/raw_data_folder/instance_data/NBDC/')
# ('Dset sizes', (33143, 13), (4277, 13))
# ---------------------------------
# ('Linkedlifedata-Chebi', 'final/raw_data_folder/instance_data/Linkedlifedata/Linkedlifedata-Chebi/')
# ('Dset sizes', (116, 13), (0, 1))
# ---------------------------------
# ('Linkedlifedata', 'final/raw_data_folder/instance_data/Linkedlifedata/Linkedlifedata/')
# No folder path found -  XXX
# ---------------------------------
# ('EBI-Ensembl', 'final/raw_data_folder/instance_data/EBI/EBI-Ensembl/')
# ('Dset sizes', (2259, 13), (42, 13))
# ---------------------------------
# ('Bio2Rdf-Wormbase', 'final/raw_data_folder/instance_data/Bio2Rdf/Bio2Rdf/')
# ('Dset sizes', (8919, 13), (436, 13))
# ---------------------------------
# ('NBDC-DDBJ', 'final/raw_data_folder/instance_data/NBDC/')
# ('Dset sizes', (33143, 13), (4277, 13))
# ---------------------------------
# ('Bio2Rdf-Affymetrix', 'final/raw_data_folder/instance_data/Bio2Rdf/Bio2Rdf/')
# ('Dset sizes', (8919, 13), (436, 13))
# ---------------------------------
# ('NBDC-Paconto', 'final/raw_data_folder/instance_data/NBDC/')
# ('Dset sizes', (33143, 13), (4277, 13))
# ---------------------------------
# ('Linkedlifedata-Cellmap', 'final/raw_data_folder/instance_data/Linkedlifedata/Linkedlifedata-Cellmap/')
# ('Dset sizes', (138, 13), (7, 13))
# ---------------------------------
# ('Linkedlifedata-Biogrid', 'final/raw_data_folder/instance_data/Linkedlifedata/Linkedlifedata-Biogrid/')
# ('Dset sizes', (85, 13), (5, 13))
# ---------------------------------
# ('Linkedlifedata-Uniprot', 'final/raw_data_folder/instance_data/Linkedlifedata/Linkedlifedata-Uniprot/')
# ('Dset sizes', (119, 13), (5, 13))
# ---------------------------------
# ('EBI-UniProt', 'final/raw_data_folder/instance_data/EBI/EBI-UniProt/')
# ('Dset sizes', (96, 13), (7, 13))
# ---------------------------------
# ('EBI-ExpressionAtlas', 'final/raw_data_folder/instance_data/EBI/EBI-ExpressionAtlas/')
# ('Dset sizes', (7634, 13), (23, 13))
# ---------------------------------
# ('Linkedlifedata-Geneontology', 'final/raw_data_folder/instance_data/Linkedlifedata/Linkedlifedata-Geneontology/')
# ('Dset sizes', (119, 13), (0, 1))
# ---------------------------------
# ('Bio2Rdf-Drugbank', 'final/raw_data_folder/instance_data/Bio2Rdf/Bio2Rdf/')
# ('Dset sizes', (8919, 13), (436, 13))
# ---------------------------------
# ('Bio2Rdf-Irefindex', 'final/raw_data_folder/instance_data/Bio2Rdf/Bio2Rdf/')
# ('Dset sizes', (8919, 13), (436, 13))
# ---------------------------------
# ('Bio2Rdf-Homologene', 'final/raw_data_folder/instance_data/Bio2Rdf/Bio2Rdf-Homologene/')
# ('Dset sizes', (87, 13), (4, 13))
# ---------------------------------
# ('NextProt', 'final/raw_data_folder/instance_data/NextProt/')
# ('Dset sizes', (931, 13), (108, 13))
# ---------------------------------
# ('ModelOrganism-Ratmine', 'final/raw_data_folder/instance_data/ModelOrganism/')
# ('Dset sizes', (6317, 13), (91, 13))
# ---------------------------------
# ('DisGenet', 'final/raw_data_folder/instance_data/DisGenet/')
# ('Dset sizes', (1315, 13), (64, 13))
# ---------------------------------
# ('Linkedlifedata-Biopax3', 'final/raw_data_folder/instance_data/Linkedlifedata/Linkedlifedata-Biopax3/')
# ('Dset sizes', (459, 13), (10, 13))
# ---------------------------------
# ('Linkedlifedata-Diseaseontology', 'final/raw_data_folder/instance_data/Linkedlifedata/Linkedlifedata-Diseaseontology/')
# ('Dset sizes', (118, 13), (0, 1))
# ---------------------------------
# ('Linkedlifedata-Entrezgene', 'final/raw_data_folder/instance_data/Linkedlifedata/Linkedlifedata-Entrezgene/')
# ('Dset sizes', (57, 13), (3, 13))
# ---------------------------------
# ('Bio2Rdf-Genage', 'final/raw_data_folder/instance_data/Bio2Rdf/Bio2Rdf-Genage/')
# ('Dset sizes', (124, 13), (14, 13))
# ---------------------------------
# ('Bio2Rdf-Clinicaltrials', 'final/raw_data_folder/instance_data/Bio2Rdf/Bio2Rdf/')
# ('Dset sizes', (8919, 13), (436, 13))
# ---------------------------------
# ('Linkedlifedata-Imid', 'final/raw_data_folder/instance_data/Linkedlifedata/Linkedlifedata-Imid/')
# ('Dset sizes', (94, 13), (5, 13))
# ---------------------------------
# ('Bio2Rdf-Taxonomy', 'final/raw_data_folder/instance_data/Bio2Rdf/Bio2Rdf/')
# ('Dset sizes', (8919, 13), (436, 13))
# ---------------------------------
# ('Bio2Rdf-Bioportal', 'final/raw_data_folder/instance_data/Bio2Rdf/Bio2Rdf/')
# ('Dset sizes', (8919, 13), (436, 13))
# ---------------------------------
# ('Bio2Rdf-Kegg', 'final/raw_data_folder/instance_data/Bio2Rdf/Bio2Rdf/')
# ('Dset sizes', (8919, 13), (436, 13))
# ---------------------------------
# ('EBI-Chembl', 'final/raw_data_folder/instance_data/EBI/EBI-Chembl/')
# ('Dset sizes', (928, 13), (52, 13))
# ---------------------------------
# ('SBG-CCLE', 'final/raw_data_folder/instance_data/SBG/SBG-CCLE/')
# ('Dset sizes', (137, 13), (2, 13))
# ---------------------------------
# ('Linkedlifedata-Sider', 'final/raw_data_folder/instance_data/Linkedlifedata/Linkedlifedata-Sider/')
# ('Dset sizes', (30, 13), (2, 13))
# ---------------------------------
# ('ModelOrganism-Yeastmine', 'final/raw_data_folder/instance_data/ModelOrganism/')
# ('Dset sizes', (6317, 13), (91, 13))
# ---------------------------------
# ('NBDC-WURCS', 'final/raw_data_folder/instance_data/NBDC/')
# ('Dset sizes', (33143, 13), (4277, 13))
# ---------------------------------
# ('Linkedlifedata-Pdb', 'final/raw_data_folder/instance_data/Linkedlifedata/Linkedlifedata-Pdb/')
# ('Dset sizes', (48, 13), (7, 13))
# ---------------------------------
# ('EBI-BioModels', 'final/raw_data_folder/instance_data/EBI/EBI-BioModels/')
# ('Dset sizes', (271, 13), (147, 13))
# ---------------------------------
# ('Linkedlifedata-Rxnorm', 'final/raw_data_folder/instance_data/Linkedlifedata/Linkedlifedata-Rxnorm/')
# ('Dset sizes', (804, 13), (0, 1))
# ---------------------------------
# ('MannheimRDF', 'final/raw_data_folder/instance_data/MannheimRDF/')
# ('Dset sizes', (54, 13), (4, 13))
# ---------------------------------
# ('NBDC-SSBD', 'final/raw_data_folder/instance_data/NBDC/')
# ('Dset sizes', (33143, 13), (4277, 13))
# ---------------------------------
# ('NBDC-Glycoepitope', 'final/raw_data_folder/instance_data/NBDC/')
# ('Dset sizes', (33143, 13), (4277, 13))
# ---------------------------------
# ('EBI-BioSamples', 'final/raw_data_folder/instance_data/EBI/EBI-BioSamples/')
# ('Dset sizes', (6973, 13), (31, 13))
# ---------------------------------
# ('OHDSI', 'final/raw_data_folder/instance_data/OHDSI/')
# ('Dset sizes', (227, 13), (9, 13))
# ---------------------------------
# ('Bio2Rdf-Goa', 'final/raw_data_folder/instance_data/Bio2Rdf/Bio2Rdf/')
# ('Dset sizes', (8919, 13), (436, 13))

# %%
for k in sorted(all_dsets.keys()):
    odict, ddict, datatypes, opn, dpn = prepare_property_dtype_dict(k)
    print (k, len(odict), len(ddict), len(datatypes))
    all_dsets[k]["Properties"]["Object Properties"] = odict
    all_dsets[k]["Properties"]["Data Properties"] = ddict
    all_dsets[k]["Datatypes"] = datatypes
    all_dsets[k]["Counts"]["Object Property Count"] = len(odict)
    all_dsets[k]["Counts"]["Data Property Count"] = len(ddict)
    all_dsets[k]["Counts"]["Datatypes Count"] = len(datatypes)
    all_dsets[k]["Counts"]["Object Property Realization Count"] = opn
    all_dsets[k]["Counts"]["Data Property Realization Count"] = dpn
# Out:
# ('', 1, 0, 0)
# ('Bio2Rdf-Affymetrix', 74, 75, 8)
# ('Bio2Rdf-Bioportal', 69, 48, 5)
# ('Bio2Rdf-Clinicaltrials', 59, 109, 9)
# ('Bio2Rdf-Ctd', 63, 36, 9)
# ('Bio2Rdf-Dbsnp', 13, 24, 5)
# ('Bio2Rdf-Drugbank', 68, 42, 8)
# ('Bio2Rdf-Genage', 10, 23, 5)
# ('Bio2Rdf-Goa', 61, 34, 7)
# ('Bio2Rdf-Hgnc', 34, 51, 9)
# ('Bio2Rdf-Homologene', 13, 13, 5)
# ('Bio2Rdf-Interpro', 25, 12, 4)
# ('Bio2Rdf-Irefindex', 36, 20, 6)
# ('Bio2Rdf-Kegg', 127, 89, 7)
# ('Bio2Rdf-Lsr', 38, 74, 10)
# ('Bio2Rdf-Medline', 21, 46, 6)
# ('Bio2Rdf-Mesh', 0, 0, 0)
# ('Bio2Rdf-Mgi', 21, 26, 6)
# ('Bio2Rdf-Ncbigene', 81, 44, 8)
# ('Bio2Rdf-Ndc', 11, 17, 5)
# ('Bio2Rdf-Omim', 68, 77, 7)
# ('Bio2Rdf-Pharmgkb', 66, 55, 9)
# ('Bio2Rdf-Refseq', 9, 62, 5)
# ('Bio2Rdf-Sgd', 93, 68, 10)
# ('Bio2Rdf-Sider', 7, 9, 3)
# ('Bio2Rdf-Taxonomy', 8, 34, 4)
# ('Bio2Rdf-Wormbase', 67, 34, 5)
# ('DisGenet', 128, 396, 19)
# ('EBI-BioModels', 52, 77, 13)
# ('EBI-BioSamples', 80, 168, 11)
# ('EBI-Chembl', 96, 171, 14)
# ('EBI-Ensembl', 87, 138, 14)
# ('EBI-ExpressionAtlas', 111, 157, 13)
# ('EBI-Reactome', 58, 58, 13)
# ('EBI-UniProt', 58, 40, 10)
# ('LinkedSPL', 106, 354, 11)
# ('LinkedTCGA', 1, 147, 2)
# ('Linkedlifedata', 0, 0, 0)
# ('Linkedlifedata-Biogrid', 28, 24, 9)
# ('Linkedlifedata-Biopax3', 54, 47, 9)
# ('Linkedlifedata-Cellmap', 36, 32, 9)
# ('Linkedlifedata-Chebi', 17, 27, 5)
# ('Linkedlifedata-Chembl', 21, 79, 3)
# ('Linkedlifedata-Clinicaltrials', 24, 88, 3)
# ('Linkedlifedata-Dailymed', 7, 27, 3)
# ('Linkedlifedata-Diseaseontology', 17, 29, 5)
# ('Linkedlifedata-Diseasome', 4, 18, 4)
# ('Linkedlifedata-Drugbank', 31, 114, 3)
# ('Linkedlifedata-Entrezgene', 6, 31, 3)
# ('Linkedlifedata-Geneontology', 17, 30, 5)
# ('Linkedlifedata-Homologene', 3, 22, 4)
# ('Linkedlifedata-Imid', 30, 25, 9)
# ('Linkedlifedata-Intact', 33, 27, 8)
# ('Linkedlifedata-Mint', 27, 24, 8)
# ('Linkedlifedata-Pdb', 8, 33, 3)
# ('Linkedlifedata-Pfam', 4, 20, 2)
# ('Linkedlifedata-Pfam-B', 0, 0, 0)
# ('Linkedlifedata-Phenotype', 17, 30, 5)
# ('Linkedlifedata-Pubmed', 1, 12, 3)
# ('Linkedlifedata-Rxnorm', 20, 25, 5)
# ('Linkedlifedata-Sider', 7, 15, 2)
# ('Linkedlifedata-Symptom', 17, 28, 5)
# ('Linkedlifedata-Umls', 20, 26, 5)
# ('Linkedlifedata-Uniprot', 38, 43, 9)
# ('MannheimRDF', 20, 34, 6)
# ('Mesh', 49, 69, 11)
# ('ModelOrganism', 27, 38, 11)
# ('ModelOrganism-Flymine', 175, 2, 2)
# ('ModelOrganism-Humanmine', 142, 2, 2)
# ('ModelOrganism-Mousemine', 139, 2, 2)
# ('ModelOrganism-Ratmine', 115, 2, 2)
# ('ModelOrganism-Yeastmine', 236, 3, 2)
# ('ModelOrganism-Zebrafishmine', 140, 2, 2)
# ('NBDC', 1071, 644, 18)
# ('NBDC-BMRB', 501, 2078, 2)
# ('NBDC-DDBJ', 5, 20, 3)
# ('NBDC-Famsbase', 6, 9, 4)
# ('NBDC-GGDONTO', 886, 31, 3)
# ('NBDC-Glycoepitope', 0, 2, 1)
# ('NBDC-Glytoucan', 37, 30, 7)
# ('NBDC-ICGC', 4, 60, 2)
# ('NBDC-INSDC', 3, 1, 1)
# ('NBDC-JCM', 1, 5, 3)
# ('NBDC-MBGD', 9, 35, 4)
# ('NBDC-Orth', 13, 58, 6)
# ('NBDC-PDB', 967, 3408, 3)
# ('NBDC-Paconto', 45, 53, 3)
# ('NBDC-Quanto', 12, 12, 4)
# ('NBDC-Refex', 7, 16, 4)
# ('NBDC-SSBD', 17, 12, 2)
# ('NBDC-TG-GATE', 20, 20, 6)
# ('NBDC-WURCS', 11, 14, 5)
# ('NextProt', 167, 109, 12)
# ('OHDSI', 29, 157, 6)
# ('PathwayCommons', 82, 87, 12)
# ('Pubchem', 28, 43, 6)
# ('SBG-CCLE', 30, 20, 7)
# ('SBG-TCGA', 57, 48, 7)
# ('WikiPathways', 31, 81, 5)
# ('Error generating realization for', (60, ''), u'http://www.w3.org/2000/01/rdf-schema#seeAlso', 'http://purl.bioontology.org/ontology/UATC/B05D\xe2\x80\xa6')
# ('Error generating realization for', (100, u'http://www.w3.org/2001/XMLSchema#string'), u'http://www4.wiwiss.fu-berlin.de/drugbank/resource/drugbank/genericName', 'http://purl.bioontology.org/ontology/UATC/B05D\xe2\x80\xa6')
# ('Error generating realization for', (20, u'http://www.w3.org/2001/XMLSchema#string'), u'http://schema.org/url', 'http://purl.bioontology.org/ontology/UATC/B05D\xe2\x80\xa6')
# ('Error generating realization for', (20, u'http://www.w3.org/2001/XMLSchema#string'), u'http://www4.wiwiss.fu-berlin.de/drugbank/resource/drugbank/dosageForm', 'http://purl.bioontology.org/ontology/UATC/B05D\xe2\x80\xa6')
# ('Error generating realization for', (20, u'http://www.w3.org/2001/XMLSchema#string'), u'http://schema.org/amountOfThisGood', 'http://purl.bioontology.org/ontology/UATC/B05D\xe2\x80\xa6')
# ('Error generating realization for', (100, u'http://www.w3.org/2001/XMLSchema#string'), u'http://schema.org/nonProprietaryName', 'http://purl.bioontology.org/ontology/UATC/B05D\xe2\x80\xa6')
# ('Error generating realization for', (20, u'http://www.w3.org/2001/XMLSchema#string'), u'http://schema.org/gtin13', 'http://purl.bioontology.org/ontology/UATC/B05D\xe2\x80\xa6')
# ('Error generating realization for', (40, ''), u'http://schema.org/availableStrength', 'http://purl.bioontology.org/ontology/UATC/B05D\xe2\x80\xa6')
# ('Error generating realization for', (20, u'http://www.w3.org/2001/XMLSchema#string'), u'http://www4.wiwiss.fu-berlin.de/drugbank/resource/drugbank/brandName', 'http://purl.bioontology.org/ontology/UATC/B05D\xe2\x80\xa6')
# ('Error generating realization for', (20, ''), u'http://schema.org/manufacturer', 'http://purl.bioontology.org/ontology/UATC/B05D\xe2\x80\xa6')
# ('Error generating realization for', (100, u'http://www.w3.org/2001/XMLSchema#string'), u'http://schema.org/activeIngredient', 'http://purl.bioontology.org/ontology/UATC/B05D\xe2\x80\xa6')
# ('Error generating realization for', (20, u'http://www.w3.org/2001/XMLSchema#date'), u'http://schema.org/dateModified', 'http://purl.bioontology.org/ontology/UATC/B05D\xe2\x80\xa6')
# ('Error generating realization for', (20, ''), u'http://schema.org/code', 'http://purl.bioontology.org/ontology/UATC/B05D\xe2\x80\xa6')
# ('Error generating realization for', (20, u'http://www.w3.org/2001/XMLSchema#string'), u'http://schema.org/dosageForm', 'http://purl.bioontology.org/ontology/UATC/B05D\xe2\x80\xa6')
# ('Error generating realization for', (20, u'http://www.w3.org/2001/XMLSchema#string'), u'http://schema.org/name', 'http://purl.bioontology.org/ontology/UATC/B05D\xe2\x80\xa6')
# ('Error generating realization for', (20, ''), u'http://schema.org/license', 'http://purl.bioontology.org/ontology/UATC/B05D\xe2\x80\xa6')
# ('Error generating realization for', (20, u'http://www.w3.org/2001/XMLSchema#string'), u'http://www4.wiwiss.fu-berlin.de/drugbank/resource/drugbank/atcCode', 'http://purl.bioontology.org/ontology/UATC/B05D\xe2\x80\xa6')
# ('Error generating realization for', (20, u'http://www.w3.org/2001/XMLSchema#string'), u'http://schema.org/addressCountry', 'http://purl.bioontology.org/ontology/UATC/B05D\xe2\x80\xa6')
# ('linkeddrugs', 7, 21, 3)

# %%
found_op_s = 0
found_op_n = 0
found_dp_s = 0
found_dp_n = 0

for k in all_dsets:
    op = all_dsets[k]["Properties"]['Object Properties']
    dp = all_dsets[k]["Properties"]['Data Properties']
    str_inst, num_inst, str_valid, num_valid = get_inst_data(k)
    data_count = 0
    str_relation_data = {}
    num_relation_data = {}
    if str_valid:
        str_relation_data = str_inst[str_inst['ftype'] == 'relation']
        str_relation_data = str_relation_data.set_index("index").to_dict(orient="index")
    if num_valid:
        num_relation_data = num_inst[num_inst['ftype'] == 'relation']
        num_relation_data = num_relation_data.set_index("index").to_dict(orient="index")
    for rel in op:
        has_realization = False
        for dreal in op[rel]['Realizations']:
            dreal_sp = "->".join(dreal.split("->")[0:2])
            if dreal_sp in str_relation_data:
                try:
                    instance_dict = {"Sample Instances (3)": eval(str_relation_data[dreal_sp]['samp_insts']), 
                                     "Namespaces": list(eval(str_relation_data[dreal_sp]['namespace'])), 
                                     "Is Categorical": str_relation_data[dreal_sp]['is_categorical'], 
                                     "Sample Instances Total": str_relation_data[dreal_sp]['inst_count'],
                                     'Categories': list(eval(str_relation_data[dreal_sp]['categories'])), 
                                     'Datatype': str_relation_data[dreal_sp]['dtype'], 
                                     'Instance Length (Median)': str_relation_data[dreal_sp]['lenmedian'],
                                     'Instance Length (Standard Deviation)': str_relation_data[dreal_sp]['lenstd'], 
                                     'Is String': True}
                    op[rel]['Realizations'][dreal]["Assertion Characteristics"] = instance_dict
                    found_op_s += 1
                except: continue
            elif dreal_sp in num_relation_data:
                try:
                    instance_dict = {"Sample Instances (3)": eval(num_relation_data[dreal_sp]['samp_insts']), 
                                     "Is Categorical": num_relation_data[dreal_sp]['is_categorical'], 
                                     "Sample Instances Total": num_relation_data[dreal_sp]['inst_count'],
                                     'Categories': list(eval(num_relation_data[dreal_sp]['categories'])), 
                                     'Datatype': num_relation_data[dreal_sp]['dtype'], 
                                     'Value Set (Median)': num_relation_data[dreal_sp]['valmedian'],
                                     'Value Set (Standard Deviation)': num_relation_data[dreal_sp]['valstd'], 
                                     'Normal Distribution Test (P-Value)': num_relation_data[dreal_sp]['normp'],
                                     'Normal Distribution Test (Statistic)': num_relation_data[dreal_sp]['normsk'],
                                     'Is String': False}
                    op[rel]['Realizations'][dreal]["Assertion Characteristics"] = instance_dict
                    found_op_n += 1
                except: continue
            op[rel]['Realizations'][dreal]['Assertion Count'] = int(op[rel]['Realizations'][dreal]['Assertion Count'])
            if op[rel]['Realizations'][dreal]['Assertion Count'] > 0: has_realization = True
        if has_realization:
            all_dsets[k]["Counts"]["Object Property-with-Assertion Count"] += 1
    for rel in dp:
        has_realization = False
        for dreal in dp[rel]['Realizations']:
            dreal_sp = "->".join(dreal.split("->")[0:2])
            if dreal_sp in str_relation_data:
                try:
                    instance_dict = {"Sample Instances (3)": eval(str_relation_data[dreal_sp]['samp_insts']), 
                                     "Namespaces": list(eval(str_relation_data[dreal_sp]['namespace'])), 
                                     "Is Categorical": str_relation_data[dreal_sp]['is_categorical'], 
                                     "Sample Instances Total": str_relation_data[dreal_sp]['inst_count'],
                                     'Categories': list(eval(str_relation_data[dreal_sp]['categories'])), 
                                     'Datatype': str_relation_data[dreal_sp]['dtype'], 
                                     'Instance Length (Median)': str_relation_data[dreal_sp]['lenmedian'],
                                     'Instance Length (Standard Deviation)': str_relation_data[dreal_sp]['lenstd'], 
                                     'Is String': True}
                    dp[rel]['Realizations'][dreal]["Assertion Characteristics"] = instance_dict
                    found_dp_s += 1
                except: continue
            elif dreal_sp in num_relation_data:
                try:
                    instance_dict = {"Sample Instances (3)": eval(num_relation_data[dreal_sp]['samp_insts']), 
                                     "Is Categorical": num_relation_data[dreal_sp]['is_categorical'], 
                                     "Sample Instances Total": num_relation_data[dreal_sp]['inst_count'],
                                     'Categories': list(eval(num_relation_data[dreal_sp]['categories'])), 
                                     'Datatype': num_relation_data[dreal_sp]['dtype'], 
                                     'Value Set (Median)': num_relation_data[dreal_sp]['valmedian'],
                                     'Value Set (Standard Deviation)': num_relation_data[dreal_sp]['valstd'], 
                                     'Normal Distribution Test (P-Value)': num_relation_data[dreal_sp]['normp'],
                                     'Normal Distribution Test (Statistic)': num_relation_data[dreal_sp]['normsk'],
                                     'Is String': False}
                    dp[rel]['Realizations'][dreal]["Assertion Characteristics"] = instance_dict
                    found_dp_n += 1
                except: continue
            dp[rel]['Realizations'][dreal]['Assertion Count'] = int(dp[rel]['Realizations'][dreal]['Assertion Count'])
            if dp[rel]['Realizations'][dreal]['Assertion Count'] > 0: has_realization = True
        if has_realization:
            all_dsets[k]["Counts"]["Data Property-with-Assertion Count"] += 1
# Out:
# ---------------------------------
# ('ModelOrganism-Flymine', 'final/raw_data_folder/instance_data/ModelOrganism/')
# ('Dset sizes', (6317, 13), (91, 13))
# ---------------------------------
# ('Pubchem', 'final/raw_data_folder/instance_data/Pubchem/')
# ('Dset sizes', (42837, 13), (35, 13))
# ---------------------------------
# ('Bio2Rdf-Mesh', 'final/raw_data_folder/instance_data/Bio2Rdf/Bio2Rdf/')
# ('Dset sizes', (8919, 13), (436, 13))
# ---------------------------------
# ('NBDC-BMRB', 'final/raw_data_folder/instance_data/NBDC/')
# ('Dset sizes', (33143, 13), (4277, 13))
# ---------------------------------
# ('Bio2Rdf-Interpro', 'final/raw_data_folder/instance_data/Bio2Rdf/Bio2Rdf-Interpro/')
# ('Dset sizes', (393, 13), (2, 13))
# ---------------------------------
# ('Bio2Rdf-Sider', 'final/raw_data_folder/instance_data/Bio2Rdf/Bio2Rdf/')
# ('Dset sizes', (8919, 13), (436, 13))
# ---------------------------------
# ('Linkedlifedata-Mint', 'final/raw_data_folder/instance_data/Linkedlifedata/Linkedlifedata-Mint/')
# ('Dset sizes', (129, 13), (5, 13))
# ---------------------------------
# ('EBI-Reactome', 'final/raw_data_folder/instance_data/EBI/EBI-Reactome/')
# ('Dset sizes', (278, 13), (9, 13))
# ---------------------------------
# ('Linkedlifedata-Pubmed', 'final/raw_data_folder/instance_data/Linkedlifedata/Linkedlifedata-Pubmed/')
# ('Dset sizes', (23, 13), (0, 1))
# ---------------------------------
# ('Bio2Rdf-Sgd', 'final/raw_data_folder/instance_data/Bio2Rdf/Bio2Rdf/')
# ('Dset sizes', (8919, 13), (436, 13))
# ---------------------------------
# ('WikiPathways', 'final/raw_data_folder/instance_data/WikiPathways/')
# ('Dset sizes', (293, 13), (41, 13))
# ---------------------------------
# ('Bio2Rdf-Omim', 'final/raw_data_folder/instance_data/Bio2Rdf/Bio2Rdf/')
# ('Dset sizes', (8919, 13), (436, 13))
# ---------------------------------
# ('Bio2Rdf-Dbsnp', 'final/raw_data_folder/instance_data/Bio2Rdf/Bio2Rdf-Dbsnp/')
# ('Dset sizes', (205, 13), (19, 13))
# ---------------------------------
# ('Bio2Rdf-Hgnc', 'final/raw_data_folder/instance_data/Bio2Rdf/Bio2Rdf/')
# ('Dset sizes', (8919, 13), (436, 13))
# ---------------------------------
# ('Bio2Rdf-Ndc', 'final/raw_data_folder/instance_data/Bio2Rdf/Bio2Rdf/')
# ('Dset sizes', (8919, 13), (436, 13))
# ---------------------------------
# ('ModelOrganism-Mousemine', 'final/raw_data_folder/instance_data/ModelOrganism/')
# ('Dset sizes', (6317, 13), (91, 13))
# ---------------------------------
# ('Linkedlifedata-Symptom', 'final/raw_data_folder/instance_data/Linkedlifedata/Linkedlifedata-Symptom/')
# ('Dset sizes', (117, 13), (0, 1))
# ---------------------------------
# ('ModelOrganism-Zebrafishmine', 'final/raw_data_folder/instance_data/ModelOrganism/')
# ('Dset sizes', (6317, 13), (91, 13))
# ---------------------------------
# ('NBDC-INSDC', 'final/raw_data_folder/instance_data/NBDC/')
# ('Dset sizes', (33143, 13), (4277, 13))
# ---------------------------------
# ('Bio2Rdf-Ncbigene', 'final/raw_data_folder/instance_data/Bio2Rdf/Bio2Rdf/')
# ('Dset sizes', (8919, 13), (436, 13))
# ---------------------------------
# ('Bio2Rdf-Lsr', 'final/raw_data_folder/instance_data/Bio2Rdf/Bio2Rdf/')
# ('Dset sizes', (8919, 13), (436, 13))
# ---------------------------------
# ('Linkedlifedata-Umls', 'final/raw_data_folder/instance_data/Linkedlifedata/Linkedlifedata-Umls/')
# ('Dset sizes', (1292, 13), (0, 1))
# ---------------------------------
# ('Bio2Rdf-Pharmgkb', 'final/raw_data_folder/instance_data/Bio2Rdf/Bio2Rdf/')
# ('Dset sizes', (8919, 13), (436, 13))
# ---------------------------------
# ('Linkedlifedata-Drugbank', 'final/raw_data_folder/instance_data/Linkedlifedata/Linkedlifedata-Drugbank/')
# ('Dset sizes', (174, 13), (19, 13))
# ---------------------------------
# ('ModelOrganism', 'final/raw_data_folder/instance_data/ModelOrganism/')
# ('Dset sizes', (6317, 13), (91, 13))
# ---------------------------------
# ('NBDC-Quanto', 'final/raw_data_folder/instance_data/NBDC/')
# ('Dset sizes', (33143, 13), (4277, 13))
# ---------------------------------
# ('Linkedlifedata-Pfam-B', 'final/raw_data_folder/instance_data/Linkedlifedata/Linkedlifedata-Pfam-B/')
# ('Dset sizes', (19, 13), (1, 13))
# ---------------------------------
# ('NBDC-TG-GATE', 'final/raw_data_folder/instance_data/NBDC/')
# ('Dset sizes', (33143, 13), (4277, 13))
# ---------------------------------
# ('NBDC-Glytoucan', 'final/raw_data_folder/instance_data/NBDC/')
# ('Dset sizes', (33143, 13), (4277, 13))
# ---------------------------------
# ('NBDC-JCM', 'final/raw_data_folder/instance_data/NBDC/')
# ('Dset sizes', (33143, 13), (4277, 13))
# ---------------------------------
# ('LinkedSPL', 'final/raw_data_folder/instance_data/LinkedSPL/')
# ('Dset sizes', (1010, 13), (39, 13))
# ---------------------------------
# ('linkeddrugs', 'final/raw_data_folder/instance_data/linkeddrugs/')
# ('Dset sizes', (20739, 13), (204, 13))
# ---------------------------------
# ('PathwayCommons', 'final/raw_data_folder/instance_data/PathwayCommons/')
# ('Dset sizes', (586, 13), (20, 13))
# ---------------------------------
# ('NBDC-PDB', 'final/raw_data_folder/instance_data/NBDC/')
# ('Dset sizes', (33143, 13), (4277, 13))
# ---------------------------------
# ('Linkedlifedata-Chembl', 'final/raw_data_folder/instance_data/Linkedlifedata/Linkedlifedata-Chembl/')
# ('Dset sizes', (142, 13), (11, 13))
# ---------------------------------
# ('Bio2Rdf-Ctd', 'final/raw_data_folder/instance_data/Bio2Rdf/Bio2Rdf/')
# ('Dset sizes', (8919, 13), (436, 13))
# ---------------------------------
# ('LinkedTCGA', 'final/raw_data_folder/instance_data/LinkedTCGA/')
# ('Dset sizes', (157, 13), (63, 13))
# ---------------------------------
# ('Linkedlifedata-Homologene', 'final/raw_data_folder/instance_data/Linkedlifedata/Linkedlifedata-Homologene/')
# ('Dset sizes', (19, 13), (14, 13))
# ---------------------------------
# ('NBDC-ICGC', 'final/raw_data_folder/instance_data/NBDC/')
# ('Dset sizes', (33143, 13), (4277, 13))
# ---------------------------------
# ('NBDC-Refex', 'final/raw_data_folder/instance_data/NBDC/')
# ('Dset sizes', (33143, 13), (4277, 13))
# ---------------------------------
# ('ModelOrganism-Humanmine', 'final/raw_data_folder/instance_data/ModelOrganism/')
# ('Dset sizes', (6317, 13), (91, 13))
# ---------------------------------
# ('Linkedlifedata-Dailymed', 'final/raw_data_folder/instance_data/Linkedlifedata/Linkedlifedata-Dailymed/')
# ('Dset sizes', (47, 13), (0, 1))
# ---------------------------------
# ('Linkedlifedata-Clinicaltrials', 'final/raw_data_folder/instance_data/Linkedlifedata/Linkedlifedata-Clinicaltrials/')
# ('Dset sizes', (160, 13), (6, 13))
# ---------------------------------
# ('Linkedlifedata-Diseasome', 'final/raw_data_folder/instance_data/Linkedlifedata/Linkedlifedata-Diseasome/')
# ('Dset sizes', (24, 13), (3, 13))
# ---------------------------------
# ('Linkedlifedata-Pfam', 'final/raw_data_folder/instance_data/Linkedlifedata/Linkedlifedata-Pfam/')
# ('Dset sizes', (30, 13), (1, 13))
# ---------------------------------
# ('NBDC', 'final/raw_data_folder/instance_data/NBDC/')
# ('Dset sizes', (33143, 13), (4277, 13))
# ---------------------------------
# ('SBG-TCGA', 'final/raw_data_folder/instance_data/SBG/SBG-TCGA/')
# ('Dset sizes', (367, 13), (27, 13))
# ---------------------------------
# ('Linkedlifedata-Phenotype', 'final/raw_data_folder/instance_data/Linkedlifedata/Linkedlifedata-Phenotype/')
# ('Dset sizes', (119, 13), (0, 1))
# ---------------------------------
# ('NBDC-Orth', 'final/raw_data_folder/instance_data/NBDC/')
# ('Dset sizes', (33143, 13), (4277, 13))
# ---------------------------------
# ('Linkedlifedata-Intact', 'final/raw_data_folder/instance_data/Linkedlifedata/Linkedlifedata-Intact/')
# ('Dset sizes', (161, 13), (6, 13))
# ---------------------------------
# ('Bio2Rdf-Medline', 'final/raw_data_folder/instance_data/Bio2Rdf/Bio2Rdf-Medline/')
# ('Dset sizes', (256, 13), (10, 13))
# ---------------------------------
# ('NBDC-MBGD', 'final/raw_data_folder/instance_data/NBDC/')
# ('Dset sizes', (33143, 13), (4277, 13))
# ---------------------------------
# ('NBDC-GGDONTO', 'final/raw_data_folder/instance_data/NBDC/')
# ('Dset sizes', (33143, 13), (4277, 13))
# ---------------------------------
# ('Bio2Rdf-Mgi', 'final/raw_data_folder/instance_data/Bio2Rdf/Bio2Rdf/')
# ('Dset sizes', (8919, 13), (436, 13))
# ---------------------------------
# ('Bio2Rdf-Refseq', 'final/raw_data_folder/instance_data/Bio2Rdf/Bio2Rdf-Refseq/')
# ('Dset sizes', (330, 13), (18, 13))
# ---------------------------------
# ('Mesh', 'final/raw_data_folder/instance_data/Mesh/')
# ('Dset sizes', (241, 13), (12, 13))
# ---------------------------------
# ('NBDC-Famsbase', 'final/raw_data_folder/instance_data/NBDC/')
# ('Dset sizes', (33143, 13), (4277, 13))
# ---------------------------------
# ('Linkedlifedata-Chebi', 'final/raw_data_folder/instance_data/Linkedlifedata/Linkedlifedata-Chebi/')
# ('Dset sizes', (116, 13), (0, 1))
# ---------------------------------
# ('Linkedlifedata', 'final/raw_data_folder/instance_data/Linkedlifedata/Linkedlifedata/')
# No folder path found -  XXX
# ---------------------------------
# ('EBI-Ensembl', 'final/raw_data_folder/instance_data/EBI/EBI-Ensembl/')
# ('Dset sizes', (2259, 13), (42, 13))
# ---------------------------------
# ('Bio2Rdf-Wormbase', 'final/raw_data_folder/instance_data/Bio2Rdf/Bio2Rdf/')
# ('Dset sizes', (8919, 13), (436, 13))
# ---------------------------------
# ('NBDC-DDBJ', 'final/raw_data_folder/instance_data/NBDC/')
# ('Dset sizes', (33143, 13), (4277, 13))
# ---------------------------------
# ('Bio2Rdf-Affymetrix', 'final/raw_data_folder/instance_data/Bio2Rdf/Bio2Rdf/')
# ('Dset sizes', (8919, 13), (436, 13))
# ---------------------------------
# ('NBDC-Paconto', 'final/raw_data_folder/instance_data/NBDC/')
# ('Dset sizes', (33143, 13), (4277, 13))
# ---------------------------------
# ('Linkedlifedata-Cellmap', 'final/raw_data_folder/instance_data/Linkedlifedata/Linkedlifedata-Cellmap/')
# ('Dset sizes', (138, 13), (7, 13))
# ---------------------------------
# ('Linkedlifedata-Biogrid', 'final/raw_data_folder/instance_data/Linkedlifedata/Linkedlifedata-Biogrid/')
# ('Dset sizes', (85, 13), (5, 13))
# ---------------------------------
# ('Linkedlifedata-Uniprot', 'final/raw_data_folder/instance_data/Linkedlifedata/Linkedlifedata-Uniprot/')
# ('Dset sizes', (119, 13), (5, 13))
# ---------------------------------
# ('EBI-UniProt', 'final/raw_data_folder/instance_data/EBI/EBI-UniProt/')
# ('Dset sizes', (96, 13), (7, 13))
# ---------------------------------
# ('EBI-ExpressionAtlas', 'final/raw_data_folder/instance_data/EBI/EBI-ExpressionAtlas/')
# ('Dset sizes', (7634, 13), (23, 13))
# ---------------------------------
# ('Linkedlifedata-Geneontology', 'final/raw_data_folder/instance_data/Linkedlifedata/Linkedlifedata-Geneontology/')
# ('Dset sizes', (119, 13), (0, 1))
# ---------------------------------
# ('Bio2Rdf-Drugbank', 'final/raw_data_folder/instance_data/Bio2Rdf/Bio2Rdf/')
# ('Dset sizes', (8919, 13), (436, 13))
# ---------------------------------
# ('Bio2Rdf-Irefindex', 'final/raw_data_folder/instance_data/Bio2Rdf/Bio2Rdf/')
# ('Dset sizes', (8919, 13), (436, 13))
# ---------------------------------
# ('Bio2Rdf-Homologene', 'final/raw_data_folder/instance_data/Bio2Rdf/Bio2Rdf-Homologene/')
# ('Dset sizes', (87, 13), (4, 13))
# ---------------------------------
# ('NextProt', 'final/raw_data_folder/instance_data/NextProt/')
# ('Dset sizes', (931, 13), (108, 13))
# ---------------------------------
# ('ModelOrganism-Ratmine', 'final/raw_data_folder/instance_data/ModelOrganism/')
# ('Dset sizes', (6317, 13), (91, 13))
# ---------------------------------
# ('DisGenet', 'final/raw_data_folder/instance_data/DisGenet/')
# ('Dset sizes', (1315, 13), (64, 13))
# ---------------------------------
# ('Linkedlifedata-Biopax3', 'final/raw_data_folder/instance_data/Linkedlifedata/Linkedlifedata-Biopax3/')
# ('Dset sizes', (459, 13), (10, 13))
# ---------------------------------
# ('Linkedlifedata-Diseaseontology', 'final/raw_data_folder/instance_data/Linkedlifedata/Linkedlifedata-Diseaseontology/')
# ('Dset sizes', (118, 13), (0, 1))
# ---------------------------------
# ('Linkedlifedata-Entrezgene', 'final/raw_data_folder/instance_data/Linkedlifedata/Linkedlifedata-Entrezgene/')
# ('Dset sizes', (57, 13), (3, 13))
# ---------------------------------
# ('Bio2Rdf-Genage', 'final/raw_data_folder/instance_data/Bio2Rdf/Bio2Rdf-Genage/')
# ('Dset sizes', (124, 13), (14, 13))
# ---------------------------------
# ('Bio2Rdf-Clinicaltrials', 'final/raw_data_folder/instance_data/Bio2Rdf/Bio2Rdf/')
# ('Dset sizes', (8919, 13), (436, 13))
# ---------------------------------
# ('Linkedlifedata-Imid', 'final/raw_data_folder/instance_data/Linkedlifedata/Linkedlifedata-Imid/')
# ('Dset sizes', (94, 13), (5, 13))
# ---------------------------------
# ('Bio2Rdf-Taxonomy', 'final/raw_data_folder/instance_data/Bio2Rdf/Bio2Rdf/')
# ('Dset sizes', (8919, 13), (436, 13))
# ---------------------------------
# ('Bio2Rdf-Bioportal', 'final/raw_data_folder/instance_data/Bio2Rdf/Bio2Rdf/')
# ('Dset sizes', (8919, 13), (436, 13))
# ---------------------------------
# ('Bio2Rdf-Kegg', 'final/raw_data_folder/instance_data/Bio2Rdf/Bio2Rdf/')
# ('Dset sizes', (8919, 13), (436, 13))
# ---------------------------------
# ('EBI-Chembl', 'final/raw_data_folder/instance_data/EBI/EBI-Chembl/')
# ('Dset sizes', (928, 13), (52, 13))
# ---------------------------------
# ('SBG-CCLE', 'final/raw_data_folder/instance_data/SBG/SBG-CCLE/')
# ('Dset sizes', (137, 13), (2, 13))
# ---------------------------------
# ('Linkedlifedata-Sider', 'final/raw_data_folder/instance_data/Linkedlifedata/Linkedlifedata-Sider/')
# ('Dset sizes', (30, 13), (2, 13))
# ---------------------------------
# ('ModelOrganism-Yeastmine', 'final/raw_data_folder/instance_data/ModelOrganism/')
# ('Dset sizes', (6317, 13), (91, 13))
# ---------------------------------
# ('NBDC-WURCS', 'final/raw_data_folder/instance_data/NBDC/')
# ('Dset sizes', (33143, 13), (4277, 13))
# ---------------------------------
# ('Linkedlifedata-Pdb', 'final/raw_data_folder/instance_data/Linkedlifedata/Linkedlifedata-Pdb/')
# ('Dset sizes', (48, 13), (7, 13))
# ---------------------------------
# ('EBI-BioModels', 'final/raw_data_folder/instance_data/EBI/EBI-BioModels/')
# ('Dset sizes', (271, 13), (147, 13))
# ---------------------------------
# ('Linkedlifedata-Rxnorm', 'final/raw_data_folder/instance_data/Linkedlifedata/Linkedlifedata-Rxnorm/')
# ('Dset sizes', (804, 13), (0, 1))
# ---------------------------------
# ('MannheimRDF', 'final/raw_data_folder/instance_data/MannheimRDF/')
# ('Dset sizes', (54, 13), (4, 13))
# ---------------------------------
# ('NBDC-SSBD', 'final/raw_data_folder/instance_data/NBDC/')
# ('Dset sizes', (33143, 13), (4277, 13))
# ---------------------------------
# ('NBDC-Glycoepitope', 'final/raw_data_folder/instance_data/NBDC/')
# ('Dset sizes', (33143, 13), (4277, 13))
# ---------------------------------
# ('EBI-BioSamples', 'final/raw_data_folder/instance_data/EBI/EBI-BioSamples/')
# ('Dset sizes', (6973, 13), (31, 13))
# ---------------------------------
# ('OHDSI', 'final/raw_data_folder/instance_data/OHDSI/')
# ('Dset sizes', (227, 13), (9, 13))
# ---------------------------------
# ('Bio2Rdf-Goa', 'final/raw_data_folder/instance_data/Bio2Rdf/Bio2Rdf/')
# ('Dset sizes', (8919, 13), (436, 13))

# %% [markdown]
# # --------------------
# #### Prepare Properties file
# # --------------------

# %%
def get_property_sets_refine(psets, ponto_nodes, pvocab_nodes, ptype):
    property_sets = deepcopy(psets)
    for k in property_sets:
        parsed_label, sec_label = get_labels(k)
        #print (parsed_label, sec_label)
        if k in ponto_nodes: oin_onto = ponto_nodes[k]
        else: oin_onto = ""
        if k in pvocab_nodes: oin_vocab = pvocab_nodes[k]
        else: oin_vocab = ""
        shared_dsets = []
        realization_count = []
        assertion_count = []
        for m in all_dsets:
            if k in all_dsets[m]["Properties"][ptype]:
                shared_dsets.append(m)
                real = all_dsets[m]["Properties"][ptype][k]['Realizations']
                realization_count.append(int(len(real)))
                assertions = int(np.sum([real[n]['Assertion Count'] for n in real]))
                assertion_count.append(assertions)
        property_sets[k] = {"ParsedLabel": parsed_label, "ExternalLabel": sec_label, "FromBioOntology": oin_onto,
                            "FromLOVVocabulary": oin_vocab, "Datasets": ":-:".join(shared_dsets), 
                            "DatasetCount": len(shared_dsets), 
                            "RealizationCount": ":-:".join([str(n) for n in realization_count]), 
                            "TotalRealizationCount": np.sum(realization_count), 
                            "AssertionCount": ":-:".join([str(n) for n in assertion_count]), 
                            "TotalAssertionCount": np.sum(assertion_count)}
    property_sets_df = pd.DataFrame.from_dict(property_sets, orient="index")
    property_sets_df = property_sets_df.reset_index()
    property_sets_df = property_sets_df.sort_values("TotalAssertionCount", ascending=False)
    property_sets_df = property_sets_df[[u'index', u'ParsedLabel', u'ExternalLabel', u'FromBioOntology', 
                                u'FromLOVVocabulary', u'Datasets', u'DatasetCount', 
                                u'RealizationCount', u'TotalRealizationCount', u'AssertionCount', 
                                u'TotalAssertionCount']]
    return property_sets_df

# %%
oproperty_sets_df = get_property_sets_refine(oproperty_sets, oproponto_nodes, opropvocab_nodes, "Object Properties")
dproperty_sets_df = get_property_sets_refine(dproperty_sets, dproponto_nodes, dpropvocab_nodes, "Data Properties")

# %%
dproperty_sets_df.to_csv("final/Extracted_Data_Properties.tsv", sep="\t", index=None)
oproperty_sets_df.to_csv("final/Extracted_Object_Properties.tsv", sep="\t", index=None)

# %% [markdown]
# # --------------------
# #### Prepare Datatypes file
# # --------------------

# %%
all_datatypes = {}
for k in all_dsets:
    dtypes = all_dsets[k]["Datatypes"]
    for m in dtypes:
        if len(m) == 0: continue
        if not m in all_datatypes: all_datatypes[m] = {"Datasets": set([])}
        all_datatypes[m]["Datasets"].add(k)

print (len(all_datatypes))
# Out:
# 24

# %%
all_datatypes_df = pd.DataFrame.from_dict(all_datatypes, orient="index")
all_datatypes_df = all_datatypes_df.reset_index()
all_datatypes_df = pd.concat([all_datatypes_df["index"], all_datatypes_df["Datasets"].apply(lambda x: ":-:".join(list(x))), 
                              all_datatypes_df["Datasets"].apply(lambda x: len(x)).to_frame(name="DatasetCount")], axis=1)
all_datatypes_df = all_datatypes_df.sort_values("DatasetCount", ascending=False)
all_datatypes_df.to_csv("final/Extracted_Datatypes.tsv", sep="\t", index=None)
all_datatypes_df.head()
# Out:
#                                                 index  \
# 21            http://www.w3.org/2001/XMLSchema#string
# 4   http://www.w3.org/1999/02/22-rdf-syntax-ns#lan...
# 17           http://www.w3.org/2001/XMLSchema#integer
# 6             http://www.w3.org/2001/XMLSchema#anyURI
# 3   http://www.w3.org/1999/02/22-rdf-syntax-ns#XML...
#
#                                              Datasets  DatasetCount
# 21  ModelOrganism-Flymine:-:Pubchem:-:NBDC-BMRB:-:...            96
# 4   Bio2Rdf-Homologene:-:Linkedlifedata-Drugbank:-...            63
# 17  NextProt:-:Linkedlifedata-Intact:-:ModelOrgani...            56
# 6   Bio2Rdf-Drugbank:-:ModelOrganism:-:NextProt:-:...            45
# 3   ModelOrganism:-:Linkedlifedata-Biogrid:-:Linke...            35

# %% [markdown]
# # --------------------
# #### Prepare DSets file
# # --------------------

# %%
del all_dsets[""]
print ("Removing non-source", len(all_dsets))
# Out:
# ('Removing non-source', 99)

# %%
dset_print = {}
print_attr = ["SPARQL Endpoint", "Class Count", "Object Property Count", 
              "Data Property Count", "Object Property Realization Count", "Data Property Realization Count", 
              "Datatypes Count", "Class-with-Instance Count", "Data Property-with-Assertion Count", 
              "Object Property-with-Assertion Count"]
for k in all_dsets:
    if len(k) == 0: continue
    dset_print[k] = {}
    for m in print_attr:
        if not "count" in m.lower(): dset_print[k][m] = all_dsets[k][m]
        else: dset_print[k][m] = all_dsets[k]["Counts"][m]
    dset_print[k]["Class Instance Coverage"] = float(all_dsets[k]["Counts"]["Class-with-Instance Count"])/all_dsets[k]["Counts"]["Class Count"]

dset_print = pd.DataFrame.from_dict(dset_print, orient="index")
dset_print = dset_print.reset_index()
dset_print = dset_print[["index", "SPARQL Endpoint", "Class Count", "Object Property Count", 
              "Data Property Count", "Object Property Realization Count", "Data Property Realization Count", 
              "Datatypes Count", "Class-with-Instance Count", 
              "Object Property-with-Assertion Count", "Data Property-with-Assertion Count", "Class Instance Coverage"]]
dset_print.to_csv("final/Linked_Dataset_Graphs.tsv", sep="\t", index=None)

# %%
dset_print.head(30)
# Out:
#                      index                            SPARQL Endpoint  \
# 0       Bio2Rdf-Affymetrix            http://sparql.openlifedata.org/
# 1        Bio2Rdf-Bioportal            http://sparql.openlifedata.org/
# 2   Bio2Rdf-Clinicaltrials            http://sparql.openlifedata.org/
# 3              Bio2Rdf-Ctd            http://sparql.openlifedata.org/
# 4            Bio2Rdf-Dbsnp            http://sparql.openlifedata.org/
# 5         Bio2Rdf-Drugbank            http://sparql.openlifedata.org/
# 6           Bio2Rdf-Genage            http://sparql.openlifedata.org/
# 7              Bio2Rdf-Goa            http://sparql.openlifedata.org/
# 8             Bio2Rdf-Hgnc            http://sparql.openlifedata.org/
# 9       Bio2Rdf-Homologene            http://sparql.openlifedata.org/
# 10        Bio2Rdf-Interpro            http://sparql.openlifedata.org/
# 11       Bio2Rdf-Irefindex            http://sparql.openlifedata.org/
# 12            Bio2Rdf-Kegg            http://sparql.openlifedata.org/
# 13             Bio2Rdf-Lsr            http://sparql.openlifedata.org/
# 14         Bio2Rdf-Medline            http://sparql.openlifedata.org/
# 15            Bio2Rdf-Mesh            http://sparql.openlifedata.org/
# 16             Bio2Rdf-Mgi            http://sparql.openlifedata.org/
# 17        Bio2Rdf-Ncbigene            http://sparql.openlifedata.org/
# 18             Bio2Rdf-Ndc            http://sparql.openlifedata.org/
# 19            Bio2Rdf-Omim            http://sparql.openlifedata.org/
# 20        Bio2Rdf-Pharmgkb            http://sparql.openlifedata.org/
# 21          Bio2Rdf-Refseq            http://sparql.openlifedata.org/
# 22             Bio2Rdf-Sgd            http://sparql.openlifedata.org/
# 23           Bio2Rdf-Sider            http://sparql.openlifedata.org/
# 24        Bio2Rdf-Taxonomy            http://sparql.openlifedata.org/
# 25        Bio2Rdf-Wormbase            http://sparql.openlifedata.org/
# 26                DisGenet            http://rdf.disgenet.org/sparql/
# 27           EBI-BioModels  https://www.ebi.ac.uk/rdf/services/sparql
# 28          EBI-BioSamples  https://www.ebi.ac.uk/rdf/services/sparql
# 29              EBI-Chembl  https://www.ebi.ac.uk/rdf/services/sparql
#
#     Class Count  Object Property Count  Data Property Count  \
# 0            75                     74                   75
# 1            57                     69                   48
# 2            62                     59                  109
# 3            49                     63                   36
# 4            16                     13                   24
# 5           107                     68                   42
# 6            12                     10                   23
# 7            17                     61                   34
# 8            43                     34                   51
# 9            24                     13                   13
# 10           30                     25                   12
# 11           89                     36                   20
# 12           99                    127                   89
# 13           11                     38                   74
# 14           19                     21                   46
# 15           12                      0                    0
# 16           37                     21                   26
# 17           40                     81                   44
# 18           14                     11                   17
# 19           64                     68                   77
# 20           73                     66                   55
# 21           27                      9                   62
# 22           88                     93                   68
# 23            9                      7                    9
# 24            8                      8                   34
# 25           45                     67                   34
# 26          100                    128                  396
# 27           28                     52                   77
# 28         1244                     80                  168
# 29          136                     96                  171
#
#     Object Property Realization Count  Data Property Realization Count  \
# 0                                 654                              907
# 1                                 451                              687
# 2                                 591                              828
# 3                                 702                              772
# 4                                 193                              449
# 5                                 884                             1066
# 6                                 145                              382
# 7                                 356                              432
# 8                                 625                              779
# 9                                 197                              413
# 10                                297                              488
# 11                               1828                             1148
# 12                                846                             1168
# 13                                140                              386
# 14                                153                              444
# 15                                  0                                0
# 16                                249                              520
# 17                                937                              827
# 18                                 65                              201
# 19                                753                             1010
# 20                                907                             1089
# 21                                246                              659
# 22                               1107                             1209
# 23                                 31                              204
# 24                                102                              270
# 25                                430                              594
# 26                               2218                             2851
# 27                               1130                              639
# 28                               3321                             6820
# 29                               1980                             1665
#
#     Datatypes Count  Class-with-Instance Count  \
# 0                 8                         75
# 1                 5                         57
# 2                 9                         62
# 3                 9                         49
# 4                 5                         16
# 5                 8                        107
# 6                 5                         12
# 7                 7                         17
# 8                 9                         43
# 9                 5                         10
# 10                4                         30
# 11                6                         89
# 12                7                         99
# 13               10                         11
# 14                6                         19
# 15                0                         12
# 16                6                         37
# 17                8                         40
# 18                5                         14
# 19                7                         64
# 20                9                         73
# 21                5                         27
# 22               10                         88
# 23                3                          9
# 24                4                          8
# 25                5                         45
# 26               19                         83
# 27               13                         28
# 28               11                       1231
# 29               14                        136
#
#     Object Property-with-Assertion Count  Data Property-with-Assertion Count  \
# 0                                     73                                  75
# 1                                     68                                  48
# 2                                     58                                 109
# 3                                     62                                  36
# 4                                     12                                  24
# 5                                     67                                  42
# 6                                      9                                  23
# 7                                     60                                  34
# 8                                     32                                  51
# 9                                     12                                  13
# 10                                    24                                  12
# 11                                    35                                  20
# 12                                   124                                  89
# 13                                    37                                  74
# 14                                    20                                  46
# 15                                     0                                   0
# 16                                    20                                  26
# 17                                    79                                  44
# 18                                    10                                  17
# 19                                    67                                  77
# 20                                    65                                  55
# 21                                     8                                  62
# 22                                    92                                  68
# 23                                     6                                   9
# 24                                     7                                  34
# 25                                    66                                  34
# 26                                   121                                 396
# 27                                    50                                  77
# 28                                    70                                 168
# 29                                    90                                 171
#
#     Class Instance Coverage
# 0                  1.000000
# 1                  1.000000
# 2                  1.000000
# 3                  1.000000
# 4                  1.000000
# 5                  1.000000
# 6                  1.000000
# 7                  1.000000
# 8                  1.000000
# 9                  0.416667
# 10                 1.000000
# 11                 1.000000
# 12                 1.000000
# 13                 1.000000
# 14                 1.000000
# 15                 1.000000
# 16                 1.000000
# 17                 1.000000
# 18                 1.000000
# 19                 1.000000
# 20                 1.000000
# 21                 1.000000
# 22                 1.000000
# 23                 1.000000
# 24                 1.000000
# 25                 1.000000
# 26                 0.830000
# 27                 1.000000
# 28                 0.989550
# 29                 1.000000

# %%
mfio.save_matrix(all_dsets, "final/LSLOD_Schema_Graph.json.pickle")

# %%
with open("final/LSLOD_Schema_Graph.json", "w") as f:
    json.dump(all_dsets, f, indent=4, sort_keys=True, encoding='utf-8', ensure_ascii=False)
